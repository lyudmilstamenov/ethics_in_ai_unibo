# %%
import pandas as pd
import numpy as np

from utils.feature_engineering import *
from utils.data_cleaning import *

from sklearn.model_selection import train_test_split
from sklearn.ensemble import HistGradientBoostingClassifier 
from sklearn.metrics import accuracy_score, classification_report, f1_score


from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
from geopy.geocoders import Nominatim
from geopy.distance import geodesic
import time 
import warnings 


warnings.filterwarnings('ignore')
# Out:
# 2025-05-18 09:39:14.517668: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-18 09:39:14.755892: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Load the data

# %%
import pandas as pd 
pd.set_option('display.max_columns', None)  
df = pd.read_excel('../Dataset_2.0_Akkodis.xlsx')
df
# Out:
#           ID  Candidate State      Age Range  \
# 0      71470            Hired  31 - 35 years
# 1      71470            Hired  31 - 35 years
# 2      71470            Hired  31 - 35 years
# 3      71470            Hired  31 - 35 years
# 4      71470            Hired  31 - 35 years
# ...      ...              ...            ...
# 21372  79993            Hired  26 - 30 years
# 21373  79993            Hired  26 - 30 years
# 21374  79993            Hired  26 - 30 years
# 21375  79993            Hired  26 - 30 years
# 21376  79993            Hired  26 - 30 years
#
#                                   Residence   Sex  Protected category  \
# 0                  TURIN » Turin ~ Piedmont  Male                 NaN
# 1                  TURIN » Turin ~ Piedmont  Male                 NaN
# 2                  TURIN » Turin ~ Piedmont  Male                 NaN
# 3                  TURIN » Turin ~ Piedmont  Male                 NaN
# 4                  TURIN » Turin ~ Piedmont  Male                 NaN
# ...                                     ...   ...                 ...
# 21372  TORRE ANNUNZIATA » Naples ~ Campania  Male                 NaN
# 21373  TORRE ANNUNZIATA » Naples ~ Campania  Male                 NaN
# 21374  TORRE ANNUNZIATA » Naples ~ Campania  Male                 NaN
# 21375  TORRE ANNUNZIATA » Naples ~ Campania  Male                 NaN
# 21376  TORRE ANNUNZIATA » Naples ~ Campania  Male                 NaN
#
#                                                      TAG  \
# 0      AUTOSAR, CAN, C, C++, MATLAB/SIMULINK, VECTOR/...
# 1      AUTOSAR, CAN, C, C++, MATLAB/SIMULINK, VECTOR/...
# 2      AUTOSAR, CAN, C, C++, MATLAB/SIMULINK, VECTOR/...
# 3      AUTOSAR, CAN, C, C++, MATLAB/SIMULINK, VECTOR/...
# 4      AUTOSAR, CAN, C, C++, MATLAB/SIMULINK, VECTOR/...
# ...                                                  ...
# 21372                                                  X
# 21373                                                  X
# 21374                                                  X
# 21375                                                  X
# 21376                                                  X
#
#                                 Study area       Study Title  \
# 0      Automation/Mechatronics Engineering  Five-year degree
# 1      Automation/Mechatronics Engineering  Five-year degree
# 2      Automation/Mechatronics Engineering  Five-year degree
# 3      Automation/Mechatronics Engineering  Five-year degree
# 4      Automation/Mechatronics Engineering  Five-year degree
# ...                                    ...               ...
# 21372                 chemical engineering  Five-year degree
# 21373                 chemical engineering  Five-year degree
# 21374                 chemical engineering  Five-year degree
# 21375                 chemical engineering  Five-year degree
# 21376                 chemical engineering  Five-year degree
#
#        Years Experience      Sector                 Last Role  \
# 0                 [1-3]  Automotive  Diagnostic/Test engineer
# 1                 [1-3]  Automotive  Diagnostic/Test engineer
# 2                 [1-3]  Automotive  Diagnostic/Test engineer
# 3                 [1-3]  Automotive  Diagnostic/Test engineer
# 4                 [1-3]  Automotive  Diagnostic/Test engineer
# ...                 ...         ...                       ...
# 21372               [0]      Others        Graduating student
# 21373               [0]      Others        Graduating student
# 21374               [0]      Others        Graduating student
# 21375               [0]      Others        Graduating student
# 21376               [0]      Others        Graduating student
#
#        Year of insertion  Year of Recruitment  \
# 0                 [2018]               [2021]
# 1                 [2018]               [2021]
# 2                 [2018]               [2021]
# 3                 [2018]               [2021]
# 4                 [2018]               [2021]
# ...                  ...                  ...
# 21372             [2023]               [2023]
# 21373             [2023]               [2023]
# 21374             [2023]               [2023]
# 21375             [2023]               [2023]
# 21376             [2023]               [2023]
#
#                                     Recruitment Request  \
# 0      E/E Diagnostic Integration Engineer - Automotive
# 1      E/E Diagnostic Integration Engineer - Automotive
# 2      E/E Diagnostic Integration Engineer - Automotive
# 3      E/E Diagnostic Integration Engineer - Automotive
# 4      E/E Diagnostic Integration Engineer - Automotive
# ...                                                 ...
# 21372                     Junior Project Engineer (C&Q)
# 21373                     Junior Project Engineer (C&Q)
# 21374                     Junior Project Engineer (C&Q)
# 21375                     Junior Project Engineer (C&Q)
# 21376                                               NaN
#
#        Assumption Headquarters            Job Family Hiring  Job Title Hiring  \
# 0                        Milan                  Engineering        Consultant
# 1                        Milan                  Engineering        Consultant
# 2                        Milan                  Engineering        Consultant
# 3                        Milan                  Engineering        Consultant
# 4                        Milan                  Engineering        Consultant
# ...                        ...                          ...               ...
# 21372                  Pomezia  Tech Consulting & Solutions        Consultant
# 21373                  Pomezia  Tech Consulting & Solutions        Consultant
# 21374                  Pomezia  Tech Consulting & Solutions        Consultant
# 21375                  Pomezia  Tech Consulting & Solutions        Consultant
# 21376                      NaN                          NaN               NaN
#
#               event_type__val  event_feedback  linked_search__key  \
# 0      Candidate notification             NaN                 NaN
# 1                BM interview             NaN           RS18.0145
# 2                Contact note             NaN                 NaN
# 3                BM interview              OK           RS18.0114
# 4             Commercial note             NaN                 NaN
# ...                       ...             ...                 ...
# 21372            HR interview              OK           RS23.0793
# 21373  Candidate notification             NaN                 NaN
# 21374  Candidate notification             NaN                 NaN
# 21375     Technical interview              OK           RS23.0793
# 21376                     NaN             NaN                 NaN
#
#             Overall                                    Job Description  \
# 0               NaN  The candidate, inserted within a multidiscipli...
# 1               NaN  The candidate, inserted within a multidiscipli...
# 2               NaN  The candidate, inserted within a multidiscipli...
# 3      ~ 2 - Medium  The candidate, inserted within a multidiscipli...
# 4               NaN  The candidate, inserted within a multidiscipli...
# ...             ...                                                ...
# 21372    ~ 3 - High  The resource, included in a team dedicated to ...
# 21373           NaN  The resource, included in a team dedicated to ...
# 21374           NaN  The resource, included in a team dedicated to ...
# 21375  ~ 2 - Medium  The resource, included in a team dedicated to ...
# 21376           NaN                                                NaN
#
#                                        Candidate Profile  Years Experience.1  \
# 0      The ideal candidate has a degree in Electronic...               [1-3]
# 1      The ideal candidate has a degree in Electronic...               [1-3]
# 2      The ideal candidate has a degree in Electronic...               [1-3]
# 3      The ideal candidate has a degree in Electronic...               [1-3]
# 4      The ideal candidate has a degree in Electronic...               [1-3]
# ...                                                  ...                 ...
# 21372  The ideal candidate has a Master's Degree in C...                 [0]
# 21373  The ideal candidate has a Master's Degree in C...                 [0]
# 21374  The ideal candidate has a Master's Degree in C...                 [0]
# 21375  The ideal candidate has a Master's Degree in C...                 [0]
# 21376                                                NaN                 NaN
#
#        Minimum Ral  Ral Maximum       Study Level            Study Area.1  \
# 0           26-28K       30-32K  Five-year degree  electronic Engineering
# 1           26-28K       30-32K  Five-year degree  electronic Engineering
# 2           26-28K       30-32K  Five-year degree  electronic Engineering
# 3           26-28K       30-32K  Five-year degree  electronic Engineering
# 4           26-28K       30-32K  Five-year degree  electronic Engineering
# ...            ...          ...               ...                     ...
# 21372        - 20K        - 20K  Five-year degree    chemical engineering
# 21373        - 20K        - 20K  Five-year degree    chemical engineering
# 21374        - 20K        - 20K  Five-year degree    chemical engineering
# 21375          20K        - 20K  Five-year degree    chemical engineering
# 21376          NaN          NaN               NaN                     NaN
#
#        Akkodis headquarters    Current Ral   Expected Ral  Technical Skills  \
# 0                    Modena        22-24 K        24-26 K               NaN
# 1                    Modena        22-24 K        24-26 K               NaN
# 2                    Modena        22-24 K        24-26 K               NaN
# 3                    Modena        22-24 K        24-26 K               2.0
# 4                    Modena        22-24 K        24-26 K               NaN
# ...                     ...            ...            ...               ...
# 21372               Pomezia  Not available  Not available               2.0
# 21373               Pomezia  Not available  Not available               NaN
# 21374               Pomezia  Not available  Not available               NaN
# 21375               Pomezia  Not available  Not available               2.0
# 21376                   NaN  Not available  Not available               NaN
#
#        Standing/Position  Comunication  Maturity  Dynamism  Mobility  English
# 0                    NaN           NaN       NaN       NaN       NaN      NaN
# 1                    NaN           NaN       NaN       NaN       NaN      NaN
# 2                    NaN           NaN       NaN       NaN       NaN      NaN
# 3                    2.0           1.0       2.0       2.0       3.0      3.0
# 4                    NaN           NaN       NaN       NaN       NaN      NaN
# ...                  ...           ...       ...       ...       ...      ...
# 21372                2.0           3.0       3.0       3.0       3.0      3.0
# 21373                NaN           NaN       NaN       NaN       NaN      NaN
# 21374                NaN           NaN       NaN       NaN       NaN      NaN
# 21375                2.0           2.0       2.0       2.0       3.0      3.0
# 21376                NaN           NaN       NaN       NaN       NaN      NaN
#
# [21377 rows x 39 columns]

# %% [markdown]
# ## Remove rows

# %% [markdown]
# ### Drop duplicates

# %%
df = df.drop_duplicates().reset_index(drop=True)

# %% [markdown]
# ### Clean the columns' names

# %%
df = clean_dataframe_columns(df)

# %% [markdown]
# ### Create new IDs and separate different people with duplicating IDs

# %%
invariant_columns = [
    "ID",
    "Sex",
    "Job Title Hiring",
    "Study Area.1",
    "Assumption Headquarters",
    "Year of insertion",
    "Age Range",
    "Study area",
    "Study Title",
    "Years Experience",
    "Residence",
]
df = split_duplicate_ids_by_invariant_columns(df, invariant_columns)
# Out:
# 🔵 Unique IDs before cleaning: 12263
# 🟢 Unique IDs after cleaning: 13372
# 🧮 Difference: 1109 new IDs created

# %% [markdown]
# ### Extract `numer_of_searches` column

# %%
df['number_of_searches'] = pd.to_numeric(
    df['linked_search__key'].str.split('.', n=1, expand=True)[1], 
    errors='coerce'
)

# %% [markdown]
# ### Remove irrelevant columns

# %%
df = df.drop(columns=['linked_search__key', 'Year of Recruitment'])

# %% [markdown]
# ### Remove candidates in first stages

# %%
df = remove_initial_stage_candidates(df)
# Out:
# 🗂️ Removed 7440 initial-stage only candidates.

# %% [markdown]
# ### Removal of Candidates with Inconsistent Final Outcomes

# %%
state_order = ['imported', 'first contact', 'in selection', 'qm', 'economic proposal', 'vivier', 'hired']
event_order = ['cv request', 'contact note', 'hr interview', 'bm interview', 'technical interview', 
               'qualification meeting', 'economic proposal', 'candidate notification']

grouped = df.groupby('ID', group_keys=False).apply(sort_group, state_order=state_order, event_order=event_order)

df = grouped.reset_index(drop=True)

# %%
feedbacks_to_remove = [
        'OK (other candidate)', 
        'KO (lost availability)', 
        'OK (hired)', 
        'OK (waiting for departure)', 
        'KO (opportunity closed)', 
        'KO (retired)', 
        'KO (ral)', 
        'KO (proposed renunciation)'
    ]


df = remove_not_hired_valid_candidates(df, state_order=state_order, event_order=event_order, feedbacks_to_remove=feedbacks_to_remove)
# Out:
# Number of unique IDs to remove: 1040
# Total IDs before cleaning: 5932
# Total IDs after cleaning: 4892
# Total IDs removed: 1040

# %%
states_to_drop = ['vivier', 'economic proposal']

print("Before filtering:")
for c in list(set(df['Candidate State'])):
    print(f"{c}: {len(df[df['Candidate State']==c])} rows")
total_ids_before = df['ID'].nunique()

df = df[~df['Candidate State'].isin(states_to_drop)]

print("\nAfter filtering:")
for c in list(set(df['Candidate State'])):
    print(f"{c}: {len(df[df['Candidate State']==c])} rows")

total_ids_after = df['ID'].nunique()
print(f"Total IDs before cleaning: {total_ids_before}")
print(f"Total IDs after cleaning: {total_ids_after}")
print(f"Total IDs removed: {total_ids_before - total_ids_after}")
# Out:
# Before filtering:
# first contact: 3093 rows
# imported: 311 rows
# qm: 399 rows
# economic proposal: 46 rows
# vivier: 28 rows
# in selection: 3044 rows
# hired: 2143 rows
#
# After filtering:
# first contact: 3093 rows
# imported: 311 rows
# qm: 399 rows
# in selection: 3044 rows
# hired: 2143 rows
# Total IDs before cleaning: 4892
# Total IDs after cleaning: 4870
# Total IDs removed: 22

# %% [markdown]
# ## Preprocess columns

# %% [markdown]
# ### Ral Mapping

# %%
ral_mapping = {
    '- 20 K': 19000,
    '- 20K': 19000,
    '20-22 K': 21000,
    '20-22K': 21000,
    '22-24 K': 23000,
    '22-24K': 23000,
    '24-26 K': 25000,
    '24-26K': 25000,
    '26-28 K': 27000,
    '26-28K': 27000,
    '28-30 K': 29000,
    '28-30K': 29000,
    '30-32 K': 31000,
    '30-32K': 31000,
    '32-34 K': 33000,
    '32-34K': 33000,
    '34-36 K': 35000,
    '34-36K': 35000,
    '36-38 K': 37000,
    '36-38K': 37000,
    '38-40 K': 39000,
    '38-40K': 39000,
    '40-42 K': 41000,
    '40-42K': 41000,
    '42-44 K': 43000,
    '42-44K': 43000,
    '44-46 K': 45000,
    '44-46K': 45000,
    '46-48 K': 47000,
    '46-48K': 47000,
    '48-50 K': 49000,
    '48-50K': 49000,
    '+ 50 K': 55000,
    '+50K': 55000,
    '20K': 20000,
    'Not available': None,
    'Not Avail.': None,
    np.nan: None
}

ral_columns = ['Expected Ral', 'Minimum Ral', 'Ral Maximum', 'Current Ral']

for col in ral_columns:
    if col in df.columns:
        df[col] = df[col].astype(str).map(ral_mapping)
    else:
        print(f"Warning: Column '{col}' not found in the DataFrame.")

# %% [markdown]
# ### Overall mapping

# %%
print(f"The unique values of column `Overall` are {set(df['Overall'])}")
# Out:
# The unique values of column `Overall` are {'~ 3 - High', '4 - Top', nan, '~ 2 - Medium', '~ 1 - Low', '2 - Medium', '3 - High', '1 - Low', '~ 4 - Top'}

# %%
score_mapping = {
    '1 - Low': 1,
    '2 - Medium': 2,
    '3 - High': 3,
    '4 - Top': 4,
    '~ 1 - Low': 1,
    '~ 2 - Medium': 2,
    '~ 3 - High': 3,
    '~ 4 - Top': 4
}
df['Overall'] = df['Overall'].map(score_mapping)

# %% [markdown]
# ### Make the `Protected category` column boolean

# %%
df['Protected category'] = df['Protected category'].apply(lambda x: True if 'article' in str(x).lower() else False)

# %% [markdown]
# ### Remove invalid values from `Job Title Hiring`

# %%
df['Job Title Hiring'] = df['Job Title Hiring'].replace('???', None)

# %% [markdown]
# ### Aggregate Records

# %%
import pandas as pd
import re

def clean_text(text):
    if not isinstance(text, str) or not text.strip():
        return None
    if text.startswith('o '):
        text = text[1:].strip()
    text = re.sub(r'^[\-\•\*]+\s*', '', text.strip())

    text = re.sub(r'\s+', ' ', text)

    text = text.lower().strip()
    return text
    

for col in ['Candidate Profile','Last Role','Job Description','Candidate Profile']:
    df[col] = df[col].apply(clean_text)

# %%
def find_differences_by_id(df):
    ignore_columns = {'Job Description','event_feedback', 'event_type__val', "Overall", "Minimum Ral",'Ral Maximum', "Technical Skills", "Mobility", "English","Dynamism","Maturity","Comunication","Standing/Position"}
    id_groups = df.groupby('ID')
    
    for id_val, group in id_groups:
        if len(group) <= 1:
            continue

        differing_cols = []
        for col in df.columns:
            if col in ignore_columns or col == 'ID':
                continue
            unique_vals = group[col].dropna().unique()
            if len(unique_vals) > 1:
                differing_cols.append((col, unique_vals))

        if differing_cols:
            print(f"\nID: {id_val}")
            for col, vals in differing_cols:
                print(f"  → Column '{col}' differs: {list(vals)}")
            for v in vals:
                print(f'\t{v}')

find_differences_by_id(df)
# Out:
# ID: 243
#   → Column 'number_of_searches' differs: [np.float64(1248.0), np.float64(1616.0)]
# 	1248.0
# 	1616.0
#
# ID: 346
#   → Column 'number_of_searches' differs: [np.float64(291.0), np.float64(957.0)]
# 	291.0
# 	957.0
#
# ID: 369
#   → Column 'number_of_searches' differs: [np.float64(392.0), np.float64(596.0)]
# 	392.0
# 	596.0
#
# ID: 1174
#   → Column 'number_of_searches' differs: [np.float64(1282.0), np.float64(50.0)]
# 	1282.0
# 	50.0
#
# ID: 1242
#   → Column 'number_of_searches' differs: [np.float64(1102.0), np.float64(794.0), np.float64(998.0)]
# 	1102.0
# 	794.0
# 	998.0
#
# ID: 1301
#   → Column 'number_of_searches' differs: [np.float64(685.0), np.float64(531.0)]
# 	685.0
# 	531.0
#
# ID: 1636
#   → Column 'number_of_searches' differs: [np.float64(1230.0), np.float64(837.0)]
# 	1230.0
# 	837.0
#
# ID: 1664
#   → Column 'number_of_searches' differs: [np.float64(207.0), np.float64(1121.0)]
# 	207.0
# 	1121.0
#
# ID: 1828
#   → Column 'number_of_searches' differs: [np.float64(1143.0), np.float64(1116.0), np.float64(673.0)]
# 	1143.0
# 	1116.0
# 	673.0
#
# ID: 2082
#   → Column 'number_of_searches' differs: [np.float64(526.0), np.float64(350.0), np.float64(596.0)]
# 	526.0
# 	350.0
# 	596.0
#
# ID: 2153
#   → Column 'number_of_searches' differs: [np.float64(67.0), np.float64(50.0)]
# 	67.0
# 	50.0
#
# ID: 2281
#   → Column 'number_of_searches' differs: [np.float64(622.0), np.float64(73.0)]
# 	622.0
# 	73.0
#
# ID: 2457
#   → Column 'number_of_searches' differs: [np.float64(350.0), np.float64(529.0), np.float64(157.0)]
# 	350.0
# 	529.0
# 	157.0
#
# ID: 2518
#   → Column 'number_of_searches' differs: [np.float64(164.0), np.float64(1019.0)]
# 	164.0
# 	1019.0
#
# ID: 2570
#   → Column 'number_of_searches' differs: [np.float64(674.0), np.float64(847.0)]
# 	674.0
# 	847.0
#
# ID: 2690
#   → Column 'number_of_searches' differs: [np.float64(526.0), np.float64(354.0), np.float64(634.0)]
# 	526.0
# 	354.0
# 	634.0
#
# ID: 2961
#   → Column 'number_of_searches' differs: [np.float64(1219.0), np.float64(262.0)]
# 	1219.0
# 	262.0
#
# ID: 3036
#   → Column 'number_of_searches' differs: [np.float64(378.0), np.float64(572.0), np.float64(226.0)]
# 	378.0
# 	572.0
# 	226.0
#
# ID: 3261
#   → Column 'number_of_searches' differs: [np.float64(542.0), np.float64(751.0)]
# 	542.0
# 	751.0
#
# ID: 3287
#   → Column 'number_of_searches' differs: [np.float64(374.0), np.float64(81.0)]
# 	374.0
# 	81.0
#
# ID: 3874
#   → Column 'number_of_searches' differs: [np.float64(1016.0), np.float64(571.0)]
# 	1016.0
# 	571.0
#
# ID: 4028
#   → Column 'number_of_searches' differs: [np.float64(308.0), np.float64(37.0)]
# 	308.0
# 	37.0
#
# ID: 4058
#   → Column 'number_of_searches' differs: [np.float64(318.0), np.float64(1094.0), np.float64(456.0)]
# 	318.0
# 	1094.0
# 	456.0
#
# ID: 4224
#   → Column 'number_of_searches' differs: [np.float64(1580.0), np.float64(1638.0)]
# 	1580.0
# 	1638.0
#
# ID: 4619
#   → Column 'number_of_searches' differs: [np.float64(566.0), np.float64(520.0)]
# 	566.0
# 	520.0
#
# ID: 5619
#   → Column 'number_of_searches' differs: [np.float64(959.0), np.float64(182.0)]
# 	959.0
# 	182.0
#
# ID: 5626
#   → Column 'number_of_searches' differs: [np.float64(785.0), np.float64(190.0)]
# 	785.0
# 	190.0
#
# ID: 5857
#   → Column 'number_of_searches' differs: [np.float64(730.0), np.float64(689.0)]
# 	730.0
# 	689.0
#
# ID: 6155
#   → Column 'number_of_searches' differs: [np.float64(48.0), np.float64(274.0)]
# 	48.0
# 	274.0
#
# ID: 6640
#   → Column 'number_of_searches' differs: [np.float64(792.0), np.float64(843.0)]
# 	792.0
# 	843.0
#
# ID: 6761
#   → Column 'number_of_searches' differs: [np.float64(1228.0), np.float64(516.0)]
# 	1228.0
# 	516.0
#
# ID: 6989
#   → Column 'number_of_searches' differs: [np.float64(73.0), np.float64(853.0)]
# 	73.0
# 	853.0
#
# ID: 7227
#   → Column 'number_of_searches' differs: [np.float64(291.0), np.float64(355.0)]
# 	291.0
# 	355.0
#
# ID: 7305
#   → Column 'number_of_searches' differs: [np.float64(1226.0), np.float64(309.0)]
# 	1226.0
# 	309.0
#
# ID: 7586
#   → Column 'number_of_searches' differs: [np.float64(516.0), np.float64(860.0), np.float64(254.0), np.float64(1094.0), np.float64(678.0)]
# 	516.0
# 	860.0
# 	254.0
# 	1094.0
# 	678.0
#
# ID: 7593
#   → Column 'number_of_searches' differs: [np.float64(177.0), np.float64(566.0)]
# 	177.0
# 	566.0
#
# ID: 7643
#   → Column 'number_of_searches' differs: [np.float64(1087.0), np.float64(1207.0)]
# 	1087.0
# 	1207.0
#
# ID: 7694
#   → Column 'number_of_searches' differs: [np.float64(1021.0), np.float64(36.0)]
# 	1021.0
# 	36.0
#
# ID: 8109
#   → Column 'number_of_searches' differs: [np.float64(10.0), np.float64(1422.0)]
# 	10.0
# 	1422.0
#
# ID: 8209
#   → Column 'number_of_searches' differs: [np.float64(759.0), np.float64(824.0), np.float64(662.0)]
# 	759.0
# 	824.0
# 	662.0
#
# ID: 8376
#   → Column 'number_of_searches' differs: [np.float64(756.0), np.float64(377.0)]
# 	756.0
# 	377.0
#
# ID: 9242
#   → Column 'number_of_searches' differs: [np.float64(952.0), np.float64(694.0)]
# 	952.0
# 	694.0
#
# ID: 9283
#   → Column 'number_of_searches' differs: [np.float64(248.0), np.float64(150.0)]
# 	248.0
# 	150.0
#
# ID: 9346
#   → Column 'number_of_searches' differs: [np.float64(866.0), np.float64(185.0), np.float64(1757.0), np.float64(903.0)]
# 	866.0
# 	185.0
# 	1757.0
# 	903.0
#
# ID: 9445
#   → Column 'number_of_searches' differs: [np.float64(347.0), np.float64(904.0)]
# 	347.0
# 	904.0
#
# ID: 9502
#   → Column 'number_of_searches' differs: [np.float64(584.0), np.float64(178.0)]
# 	584.0
# 	178.0
#
# ID: 9872
#   → Column 'number_of_searches' differs: [np.float64(10.0), np.float64(1283.0)]
# 	10.0
# 	1283.0
#
# ID: 9923
#   → Column 'number_of_searches' differs: [np.float64(526.0), np.float64(350.0), np.float64(391.0)]
# 	526.0
# 	350.0
# 	391.0
#
# ID: 9973
#   → Column 'number_of_searches' differs: [np.float64(152.0), np.float64(856.0)]
# 	152.0
# 	856.0
#
# ID: 10101
#   → Column 'number_of_searches' differs: [np.float64(678.0), np.float64(438.0)]
# 	678.0
# 	438.0
#
# ID: 10214
#   → Column 'number_of_searches' differs: [np.float64(817.0), np.float64(284.0)]
# 	817.0
# 	284.0
#
# ID: 10243
#   → Column 'number_of_searches' differs: [np.float64(978.0), np.float64(899.0), np.float64(69.0)]
# 	978.0
# 	899.0
# 	69.0
#
# ID: 10394
#   → Column 'number_of_searches' differs: [np.float64(1724.0), np.float64(1024.0)]
# 	1724.0
# 	1024.0
#
# ID: 10831
#   → Column 'number_of_searches' differs: [np.float64(433.0), np.float64(440.0)]
# 	433.0
# 	440.0
#
# ID: 10890
#   → Column 'number_of_searches' differs: [np.float64(859.0), np.float64(383.0)]
# 	859.0
# 	383.0
#
# ID: 11033
#   → Column 'number_of_searches' differs: [np.float64(123.0), np.float64(581.0)]
# 	123.0
# 	581.0
#
# ID: 11042
#   → Column 'number_of_searches' differs: [np.float64(991.0), np.float64(904.0)]
# 	991.0
# 	904.0
#
# ID: 11099
#   → Column 'number_of_searches' differs: [np.float64(219.0), np.float64(128.0)]
# 	219.0
# 	128.0
#
# ID: 11155
#   → Column 'number_of_searches' differs: [np.float64(937.0), np.float64(403.0)]
# 	937.0
# 	403.0
#
# ID: 11564
#   → Column 'number_of_searches' differs: [np.float64(262.0), np.float64(139.0)]
# 	262.0
# 	139.0
#
# ID: 11615
#   → Column 'number_of_searches' differs: [np.float64(381.0), np.float64(688.0)]
# 	381.0
# 	688.0
#
# ID: 12047
#   → Column 'number_of_searches' differs: [np.float64(567.0), np.float64(442.0), np.float64(1308.0)]
# 	567.0
# 	442.0
# 	1308.0
#
# ID: 12574
#   → Column 'number_of_searches' differs: [np.float64(449.0), np.float64(193.0), np.float64(462.0), np.float64(195.0)]
# 	449.0
# 	193.0
# 	462.0
# 	195.0
#
# ID: 12855
#   → Column 'number_of_searches' differs: [np.float64(123.0), np.float64(129.0)]
# 	123.0
# 	129.0
#
# ID: 12897
#   → Column 'number_of_searches' differs: [np.float64(852.0), np.float64(323.0)]
# 	852.0
# 	323.0
#
# ID: 12918
#   → Column 'number_of_searches' differs: [np.float64(499.0), np.float64(946.0)]
# 	499.0
# 	946.0
#
# ID: 13101
#   → Column 'number_of_searches' differs: [np.float64(152.0), np.float64(497.0)]
# 	152.0
# 	497.0
#
# ID: 13118
#   → Column 'number_of_searches' differs: [np.float64(596.0), np.float64(1001.0)]
# 	596.0
# 	1001.0
#
# ID: 13617
#   → Column 'number_of_searches' differs: [np.float64(1459.0), np.float64(1330.0)]
# 	1459.0
# 	1330.0
#
# ID: 13899
#   → Column 'number_of_searches' differs: [np.float64(1293.0), np.float64(555.0), np.float64(938.0)]
# 	1293.0
# 	555.0
# 	938.0
#
# ID: 14010
#   → Column 'number_of_searches' differs: [np.float64(413.0), np.float64(258.0), np.float64(565.0)]
# 	413.0
# 	258.0
# 	565.0
#
# ID: 14305
#   → Column 'number_of_searches' differs: [np.float64(1724.0), np.float64(1024.0)]
# 	1724.0
# 	1024.0
#
# ID: 14374
#   → Column 'number_of_searches' differs: [np.float64(1287.0), np.float64(103.0), np.float64(565.0)]
# 	1287.0
# 	103.0
# 	565.0
#
# ID: 14572
#   → Column 'number_of_searches' differs: [np.float64(816.0), np.float64(736.0)]
# 	816.0
# 	736.0
#
# ID: 14915
#   → Column 'Candidate Profile' differs: ['excellent references for product/subsystem v&v activities for the railway sector excellent references in conducting product/system validation/integration test activities good knowledge of the alstom v&v process good knowledge of the functionality of tms systems knowledge is appreciated of products good familiarity with laboratory testing activities (in particular for functional tests on targets)', 'excellent references for product/subsystem v&v activities for the railway sector excellent references in conducting product/system validation/integration test activities good knowledge of the alstom v&v process good knowledge of the functionality of tms systems knowledge is appreciated of alstom products good familiarity with laboratory testing activities (in particular for functional tests on targets)']
# 	excellent references for product/subsystem v&v activities for the railway sector excellent references in conducting product/system validation/integration test activities good knowledge of the alstom v&v process good knowledge of the functionality of tms systems knowledge is appreciated of products good familiarity with laboratory testing activities (in particular for functional tests on targets)
# 	excellent references for product/subsystem v&v activities for the railway sector excellent references in conducting product/system validation/integration test activities good knowledge of the alstom v&v process good knowledge of the functionality of tms systems knowledge is appreciated of alstom products good familiarity with laboratory testing activities (in particular for functional tests on targets)
#
# ID: 16049
#   → Column 'number_of_searches' differs: [np.float64(43.0), np.float64(1053.0), np.float64(1278.0)]
# 	43.0
# 	1053.0
# 	1278.0
#
# ID: 16141
#   → Column 'number_of_searches' differs: [np.float64(1048.0), np.float64(36.0), np.float64(1041.0)]
# 	1048.0
# 	36.0
# 	1041.0
#
# ID: 16227
#   → Column 'number_of_searches' differs: [np.float64(781.0), np.float64(771.0)]
# 	781.0
# 	771.0
#
# ID: 17029
#   → Column 'number_of_searches' differs: [np.float64(327.0), np.float64(428.0)]
# 	327.0
# 	428.0
#
# ID: 17678
#   → Column 'Job Family Hiring' differs: ['Support', 'Enabling Function']
# 	Support
# 	Enabling Function
#
# ID: 17718
#   → Column 'number_of_searches' differs: [np.float64(738.0), np.float64(626.0), np.float64(933.0), np.float64(862.0)]
# 	738.0
# 	626.0
# 	933.0
# 	862.0
#
# ID: 17748
#   → Column 'number_of_searches' differs: [np.float64(299.0), np.float64(37.0)]
# 	299.0
# 	37.0
#
# ID: 18172
#   → Column 'number_of_searches' differs: [np.float64(88.0), np.float64(1254.0)]
# 	88.0
# 	1254.0
#
# ID: 18235
#   → Column 'number_of_searches' differs: [np.float64(298.0), np.float64(46.0)]
# 	298.0
# 	46.0
#
# ID: 18597
#   → Column 'number_of_searches' differs: [np.float64(219.0), np.float64(1285.0)]
# 	219.0
# 	1285.0
#
# ID: 18736
#   → Column 'number_of_searches' differs: [np.float64(820.0), np.float64(781.0)]
# 	820.0
# 	781.0
#
# ID: 20234
#   → Column 'number_of_searches' differs: [np.float64(1245.0), np.float64(1100.0)]
# 	1245.0
# 	1100.0
#
# ID: 20602
#   → Column 'number_of_searches' differs: [np.float64(498.0), np.float64(890.0)]
# 	498.0
# 	890.0
#
# ID: 20812
#   → Column 'number_of_searches' differs: [np.float64(1034.0), np.float64(1041.0)]
# 	1034.0
# 	1041.0
#
# ID: 21474
#   → Column 'number_of_searches' differs: [np.float64(37.0), np.float64(308.0)]
# 	37.0
# 	308.0
#
# ID: 21514
#   → Column 'number_of_searches' differs: [np.float64(209.0), np.float64(402.0)]
# 	209.0
# 	402.0
#
# ID: 21624
#   → Column 'number_of_searches' differs: [np.float64(646.0), np.float64(482.0)]
# 	646.0
# 	482.0
#
# ID: 21983
#   → Column 'number_of_searches' differs: [np.float64(123.0), np.float64(129.0)]
# 	123.0
# 	129.0
#
# ID: 22012
#   → Column 'number_of_searches' differs: [np.float64(758.0), np.float64(420.0)]
# 	758.0
# 	420.0
#
# ID: 22036
#   → Column 'number_of_searches' differs: [np.float64(809.0), np.float64(761.0)]
# 	809.0
# 	761.0
#
# ID: 22302
#   → Column 'number_of_searches' differs: [np.float64(876.0), np.float64(866.0), np.float64(367.0)]
# 	876.0
# 	866.0
# 	367.0
#
# ID: 22315
#   → Column 'number_of_searches' differs: [np.float64(692.0), np.float64(106.0), np.float64(687.0)]
# 	692.0
# 	106.0
# 	687.0
#
# ID: 22325
#   → Column 'number_of_searches' differs: [np.float64(114.0), np.float64(1071.0)]
# 	114.0
# 	1071.0
#
# ID: 22875
#   → Column 'number_of_searches' differs: [np.float64(201.0), np.float64(985.0)]
# 	201.0
# 	985.0
#
# ID: 23369
#   → Column 'number_of_searches' differs: [np.float64(164.0), np.float64(889.0)]
# 	164.0
# 	889.0
#
# ID: 23521
#   → Column 'number_of_searches' differs: [np.float64(300.0), np.float64(513.0), np.float64(438.0)]
# 	300.0
# 	513.0
# 	438.0
#
# ID: 23736
#   → Column 'number_of_searches' differs: [np.float64(443.0), np.float64(901.0)]
# 	443.0
# 	901.0
#
# ID: 24050
#   → Column 'number_of_searches' differs: [np.float64(479.0), np.float64(1186.0), np.float64(887.0), np.float64(903.0)]
# 	479.0
# 	1186.0
# 	887.0
# 	903.0
#
# ID: 24237
#   → Column 'number_of_searches' differs: [np.float64(1290.0), np.float64(405.0)]
# 	1290.0
# 	405.0
#
# ID: 24416
#   → Column 'number_of_searches' differs: [np.float64(1004.0), np.float64(1277.0)]
# 	1004.0
# 	1277.0
#
# ID: 24431
#   → Column 'number_of_searches' differs: [np.float64(1201.0), np.float64(786.0), np.float64(686.0), np.float64(682.0)]
# 	1201.0
# 	786.0
# 	686.0
# 	682.0
#
# ID: 24501
#   → Column 'number_of_searches' differs: [np.float64(162.0), np.float64(637.0)]
# 	162.0
# 	637.0
#
# ID: 24595
#   → Column 'number_of_searches' differs: [np.float64(153.0), np.float64(145.0)]
# 	153.0
# 	145.0
#
# ID: 24701
#   → Column 'number_of_searches' differs: [np.float64(55.0), np.float64(1006.0)]
# 	55.0
# 	1006.0
#
# ID: 24969
#   → Column 'number_of_searches' differs: [np.float64(177.0), np.float64(741.0)]
# 	177.0
# 	741.0
#
# ID: 25178
#   → Column 'number_of_searches' differs: [np.float64(195.0), np.float64(944.0)]
# 	195.0
# 	944.0
#
# ID: 25645
#   → Column 'number_of_searches' differs: [np.float64(359.0), np.float64(367.0)]
# 	359.0
# 	367.0
#
# ID: 26091
#   → Column 'number_of_searches' differs: [np.float64(453.0), np.float64(1094.0)]
# 	453.0
# 	1094.0
#
# ID: 26168
#   → Column 'number_of_searches' differs: [np.float64(694.0), np.float64(73.0)]
# 	694.0
# 	73.0
#
# ID: 26187
#   → Column 'number_of_searches' differs: [np.float64(537.0), np.float64(215.0)]
# 	537.0
# 	215.0
#
# ID: 26196
#   → Column 'number_of_searches' differs: [np.float64(202.0), np.float64(254.0), np.float64(573.0)]
# 	202.0
# 	254.0
# 	573.0
#
# ID: 26752
#   → Column 'number_of_searches' differs: [np.float64(914.0), np.float64(553.0), np.float64(287.0)]
# 	914.0
# 	553.0
# 	287.0
#
# ID: 27198
#   → Column 'number_of_searches' differs: [np.float64(876.0), np.float64(678.0), np.float64(274.0)]
# 	876.0
# 	678.0
# 	274.0
#
# ID: 27458
#   → Column 'number_of_searches' differs: [np.float64(709.0), np.float64(918.0)]
# 	709.0
# 	918.0
#
# ID: 27697
#   → Column 'number_of_searches' differs: [np.float64(1497.0), np.float64(654.0)]
# 	1497.0
# 	654.0
#
# ID: 27701
#   → Column 'number_of_searches' differs: [np.float64(386.0), np.float64(944.0)]
# 	386.0
# 	944.0
#
# ID: 27792
#   → Column 'number_of_searches' differs: [np.float64(810.0), np.float64(254.0), np.float64(202.0)]
# 	810.0
# 	254.0
# 	202.0
#
# ID: 27868
#   → Column 'number_of_searches' differs: [np.float64(1272.0), np.float64(1267.0)]
# 	1272.0
# 	1267.0
#
# ID: 27966
#   → Column 'number_of_searches' differs: [np.float64(508.0), np.float64(239.0)]
# 	508.0
# 	239.0
#
# ID: 27995
#   → Column 'number_of_searches' differs: [np.float64(258.0), np.float64(635.0), np.float64(367.0)]
# 	258.0
# 	635.0
# 	367.0
#
# ID: 28067
#   → Column 'number_of_searches' differs: [np.float64(148.0), np.float64(367.0)]
# 	148.0
# 	367.0
#
# ID: 28288
#   → Column 'number_of_searches' differs: [np.float64(308.0), np.float64(652.0), np.float64(911.0)]
# 	308.0
# 	652.0
# 	911.0
#
# ID: 28320
#   → Column 'number_of_searches' differs: [np.float64(443.0), np.float64(840.0)]
# 	443.0
# 	840.0
#
# ID: 28573
#   → Column 'number_of_searches' differs: [np.float64(417.0), np.float64(1209.0)]
# 	417.0
# 	1209.0
#
# ID: 29444
#   → Column 'number_of_searches' differs: [np.float64(260.0), np.float64(531.0)]
# 	260.0
# 	531.0
#
# ID: 29639
#   → Column 'number_of_searches' differs: [np.float64(932.0), np.float64(933.0)]
# 	932.0
# 	933.0
#
# ID: 29817
#   → Column 'number_of_searches' differs: [np.float64(1109.0), np.float64(1037.0), np.float64(630.0)]
# 	1109.0
# 	1037.0
# 	630.0
#
# ID: 30247
#   → Column 'number_of_searches' differs: [np.float64(1758.0), np.float64(509.0)]
# 	1758.0
# 	509.0
#
# ID: 30480
#   → Column 'number_of_searches' differs: [np.float64(703.0), np.float64(427.0)]
# 	703.0
# 	427.0
#
# ID: 30802
#   → Column 'number_of_searches' differs: [np.float64(1340.0), np.float64(1031.0)]
# 	1340.0
# 	1031.0
#
# ID: 30876
#   → Column 'number_of_searches' differs: [np.float64(707.0), np.float64(655.0)]
# 	707.0
# 	655.0
#
# ID: 31254
#   → Column 'number_of_searches' differs: [np.float64(758.0), np.float64(293.0)]
# 	758.0
# 	293.0
#
# ID: 31365
#   → Column 'number_of_searches' differs: [np.float64(531.0), np.float64(295.0)]
# 	531.0
# 	295.0
#
# ID: 31450
#   → Column 'number_of_searches' differs: [np.float64(1307.0), np.float64(43.0)]
# 	1307.0
# 	43.0
#
# ID: 31501
#   → Column 'number_of_searches' differs: [np.float64(1226.0), np.float64(284.0)]
# 	1226.0
# 	284.0
#
# ID: 31521
#   → Column 'number_of_searches' differs: [np.float64(636.0), np.float64(731.0)]
# 	636.0
# 	731.0
#
# ID: 31834
#   → Column 'number_of_searches' differs: [np.float64(595.0), np.float64(1298.0)]
# 	595.0
# 	1298.0
#
# ID: 32394
#   → Column 'number_of_searches' differs: [np.float64(180.0), np.float64(668.0)]
# 	180.0
# 	668.0
#
# ID: 32429
#   → Column 'number_of_searches' differs: [np.float64(56.0), np.float64(673.0)]
# 	56.0
# 	673.0
#
# ID: 32711
#   → Column 'number_of_searches' differs: [np.float64(117.0), np.float64(1203.0)]
# 	117.0
# 	1203.0
#
# ID: 33153
#   → Column 'number_of_searches' differs: [np.float64(942.0), np.float64(204.0), np.float64(295.0), np.float64(454.0)]
# 	942.0
# 	204.0
# 	295.0
# 	454.0
#
# ID: 33210
#   → Column 'number_of_searches' differs: [np.float64(608.0), np.float64(417.0)]
# 	608.0
# 	417.0
#
# ID: 33326
#   → Column 'number_of_searches' differs: [np.float64(36.0), np.float64(350.0)]
# 	36.0
# 	350.0
#
# ID: 33672
#   → Column 'number_of_searches' differs: [np.float64(35.0), np.float64(48.0)]
# 	35.0
# 	48.0
#
# ID: 33685
#   → Column 'number_of_searches' differs: [np.float64(120.0), np.float64(1099.0), np.float64(872.0)]
# 	120.0
# 	1099.0
# 	872.0
#
# ID: 34124
#   → Column 'number_of_searches' differs: [np.float64(527.0), np.float64(1143.0)]
# 	527.0
# 	1143.0
#
# ID: 34331
#   → Column 'number_of_searches' differs: [np.float64(404.0), np.float64(787.0)]
# 	404.0
# 	787.0
#
# ID: 34398
#   → Column 'number_of_searches' differs: [np.float64(320.0), np.float64(676.0)]
# 	320.0
# 	676.0
#
# ID: 34548
#   → Column 'number_of_searches' differs: [np.float64(1194.0), np.float64(1149.0), np.float64(876.0)]
# 	1194.0
# 	1149.0
# 	876.0
#
# ID: 34835
#   → Column 'number_of_searches' differs: [np.float64(311.0), np.float64(66.0), np.float64(683.0)]
# 	311.0
# 	66.0
# 	683.0
#
# ID: 35061
#   → Column 'number_of_searches' differs: [np.float64(991.0), np.float64(1220.0), np.float64(1282.0)]
# 	991.0
# 	1220.0
# 	1282.0
#
# ID: 35135
#   → Column 'number_of_searches' differs: [np.float64(467.0), np.float64(865.0)]
# 	467.0
# 	865.0
#
# ID: 35540
#   → Column 'number_of_searches' differs: [np.float64(49.0), np.float64(137.0)]
# 	49.0
# 	137.0
#
# ID: 35649
#   → Column 'Candidate Profile' differs: ["3 to 7 years' experience in the oil & gas industry, both onshore and offshore fields, with experience in process safety, hse or loss prevention in different project engineering phases -advanced knowledge of english language -advanced skills in the most common ms office applications and office365 suite -good communication, problem-solving and decision making -strong attitude to collaborate with colleagues also by means of it / digital tools", 'execute the process safety, hse and loss prevention activities, also at multi-disciplinary level, throughout the project. ensure discipline progress monitoring and control man-hour consumption; -execute or coordinate the main loss prevention engineering tasks (ie hazardous area classification, active and passive fire protection design, fire and gas detection system design, etc.), and manage the comments from client performed on these activities; -ensure the correct application of project procedures, engineering specifications and international codes and standards (nfpa, api, ogp, etc.); -attend to the safety reviews and assessments (hazid, hazop, sil, etc.) and manage the follow-up activity of the actions / recommendations raised during these workshops; -check and manage the risk analysis activities (qra, fera, etc.) and reliability studies (ram); -interface with client on technical issues on loss prevention design.']
# 	3 to 7 years' experience in the oil & gas industry, both onshore and offshore fields, with experience in process safety, hse or loss prevention in different project engineering phases -advanced knowledge of english language -advanced skills in the most common ms office applications and office365 suite -good communication, problem-solving and decision making -strong attitude to collaborate with colleagues also by means of it / digital tools
# 	execute the process safety, hse and loss prevention activities, also at multi-disciplinary level, throughout the project. ensure discipline progress monitoring and control man-hour consumption; -execute or coordinate the main loss prevention engineering tasks (ie hazardous area classification, active and passive fire protection design, fire and gas detection system design, etc.), and manage the comments from client performed on these activities; -ensure the correct application of project procedures, engineering specifications and international codes and standards (nfpa, api, ogp, etc.); -attend to the safety reviews and assessments (hazid, hazop, sil, etc.) and manage the follow-up activity of the actions / recommendations raised during these workshops; -check and manage the risk analysis activities (qra, fera, etc.) and reliability studies (ram); -interface with client on technical issues on loss prevention design.
#
# ID: 35687
#   → Column 'number_of_searches' differs: [np.float64(318.0), np.float64(195.0)]
# 	318.0
# 	195.0
#
# ID: 36053
#   → Column 'number_of_searches' differs: [np.float64(810.0), np.float64(778.0)]
# 	810.0
# 	778.0
#
# ID: 36289
#   → Column 'number_of_searches' differs: [np.float64(958.0), np.float64(977.0)]
# 	958.0
# 	977.0
#
# ID: 36389
#   → Column 'number_of_searches' differs: [np.float64(180.0), np.float64(1328.0)]
# 	180.0
# 	1328.0
#
# ID: 36418
#   → Column 'number_of_searches' differs: [np.float64(289.0), np.float64(290.0)]
# 	289.0
# 	290.0
#
# ID: 36750
#   → Column 'number_of_searches' differs: [np.float64(698.0), np.float64(93.0)]
# 	698.0
# 	93.0
#
# ID: 37231
#   → Column 'number_of_searches' differs: [np.float64(839.0), np.float64(865.0), np.float64(427.0)]
# 	839.0
# 	865.0
# 	427.0
#
# ID: 37499
#   → Column 'number_of_searches' differs: [np.float64(1154.0), np.float64(367.0)]
# 	1154.0
# 	367.0
#
# ID: 37540
#   → Column 'number_of_searches' differs: [np.float64(350.0), np.float64(989.0), np.float64(555.0), np.float64(367.0)]
# 	350.0
# 	989.0
# 	555.0
# 	367.0
#
# ID: 38489
#   → Column 'number_of_searches' differs: [np.float64(314.0), np.float64(118.0)]
# 	314.0
# 	118.0
#
# ID: 38540
#   → Column 'number_of_searches' differs: [np.float64(888.0), np.float64(885.0), np.float64(152.0)]
# 	888.0
# 	885.0
# 	152.0
#
# ID: 38945
#   → Column 'number_of_searches' differs: [np.float64(394.0), np.float64(420.0)]
# 	394.0
# 	420.0
#
# ID: 39205
#   → Column 'number_of_searches' differs: [np.float64(606.0), np.float64(783.0), np.float64(462.0)]
# 	606.0
# 	783.0
# 	462.0
#
# ID: 40187
#   → Column 'number_of_searches' differs: [np.float64(487.0), np.float64(48.0)]
# 	487.0
# 	48.0
#
# ID: 40213
#   → Column 'number_of_searches' differs: [np.float64(121.0), np.float64(221.0)]
# 	121.0
# 	221.0
#
# ID: 40275
#   → Column 'number_of_searches' differs: [np.float64(774.0), np.float64(182.0)]
# 	774.0
# 	182.0
#
# ID: 40511
#   → Column 'number_of_searches' differs: [np.float64(216.0), np.float64(1278.0)]
# 	216.0
# 	1278.0
#
# ID: 40624
#   → Column 'number_of_searches' differs: [np.float64(22.0), np.float64(83.0), np.float64(330.0)]
# 	22.0
# 	83.0
# 	330.0
#
# ID: 40656
#   → Column 'number_of_searches' differs: [np.float64(1618.0), np.float64(1319.0), np.float64(5.0)]
# 	1618.0
# 	1319.0
# 	5.0
#
# ID: 40843
#   → Column 'number_of_searches' differs: [np.float64(1115.0), np.float64(510.0)]
# 	1115.0
# 	510.0
#
# ID: 40845
#   → Column 'number_of_searches' differs: [np.float64(190.0), np.float64(644.0)]
# 	190.0
# 	644.0
#
# ID: 40942
#   → Column 'number_of_searches' differs: [np.float64(190.0), np.float64(1659.0), np.float64(531.0)]
# 	190.0
# 	1659.0
# 	531.0
#
# ID: 41065
#   → Column 'number_of_searches' differs: [np.float64(1418.0), np.float64(852.0), np.float64(520.0)]
# 	1418.0
# 	852.0
# 	520.0
#
# ID: 41270
#   → Column 'number_of_searches' differs: [np.float64(32.0), np.float64(667.0)]
# 	32.0
# 	667.0
#
# ID: 41586
#   → Column 'number_of_searches' differs: [np.float64(395.0), np.float64(291.0)]
# 	395.0
# 	291.0
#
# ID: 41683
#   → Column 'number_of_searches' differs: [np.float64(958.0), np.float64(949.0)]
# 	958.0
# 	949.0
#
# ID: 41802
#   → Column 'number_of_searches' differs: [np.float64(959.0), np.float64(594.0), np.float64(293.0)]
# 	959.0
# 	594.0
# 	293.0
#
# ID: 41928
#   → Column 'number_of_searches' differs: [np.float64(848.0), np.float64(379.0)]
# 	848.0
# 	379.0
#
# ID: 42352
#   → Column 'number_of_searches' differs: [np.float64(958.0), np.float64(652.0)]
# 	958.0
# 	652.0
#
# ID: 42490
#   → Column 'number_of_searches' differs: [np.float64(382.0), np.float64(1261.0)]
# 	382.0
# 	1261.0
#
# ID: 43454
#   → Column 'number_of_searches' differs: [np.float64(579.0), np.float64(44.0)]
# 	579.0
# 	44.0
#
# ID: 43617
#   → Column 'number_of_searches' differs: [np.float64(674.0), np.float64(1328.0), np.float64(885.0)]
# 	674.0
# 	1328.0
# 	885.0
#
# ID: 44133
#   → Column 'number_of_searches' differs: [np.float64(350.0), np.float64(554.0)]
# 	350.0
# 	554.0
#
# ID: 44288
#   → Column 'number_of_searches' differs: [np.float64(952.0), np.float64(806.0), np.float64(243.0)]
# 	952.0
# 	806.0
# 	243.0
#
# ID: 44616
#   → Column 'number_of_searches' differs: [np.float64(649.0), np.float64(730.0)]
# 	649.0
# 	730.0
#
# ID: 44896
#   → Column 'number_of_searches' differs: [np.float64(400.0), np.float64(44.0)]
# 	400.0
# 	44.0
#
# ID: 45822
#   → Column 'number_of_searches' differs: [np.float64(1422.0), np.float64(903.0)]
# 	1422.0
# 	903.0
#
# ID: 46208
#   → Column 'number_of_searches' differs: [np.float64(35.0), np.float64(785.0), np.float64(180.0)]
# 	35.0
# 	785.0
# 	180.0
#
# ID: 46210
#   → Column 'number_of_searches' differs: [np.float64(858.0), np.float64(303.0), np.float64(377.0)]
# 	858.0
# 	303.0
# 	377.0
#
# ID: 46216
#   → Column 'number_of_searches' differs: [np.float64(256.0), np.float64(359.0)]
# 	256.0
# 	359.0
#
# ID: 46744
#   → Column 'number_of_searches' differs: [np.float64(953.0), np.float64(96.0)]
# 	953.0
# 	96.0
#
# ID: 46756
#   → Column 'number_of_searches' differs: [np.float64(600.0), np.float64(1222.0)]
# 	600.0
# 	1222.0
#
# ID: 47231
#   → Column 'number_of_searches' differs: [np.float64(654.0), np.float64(338.0)]
# 	654.0
# 	338.0
#
# ID: 47628
#   → Column 'number_of_searches' differs: [np.float64(258.0), np.float64(1594.0), np.float64(322.0)]
# 	258.0
# 	1594.0
# 	322.0
#
# ID: 47879
#   → Column 'number_of_searches' differs: [np.float64(943.0), np.float64(684.0)]
# 	943.0
# 	684.0
#
# ID: 47974
#   → Column 'number_of_searches' differs: [np.float64(764.0), np.float64(302.0)]
# 	764.0
# 	302.0
#
# ID: 47975
#   → Column 'number_of_searches' differs: [np.float64(1274.0), np.float64(1282.0)]
# 	1274.0
# 	1282.0
#
# ID: 48479
#   → Column 'number_of_searches' differs: [np.float64(1225.0), np.float64(392.0)]
# 	1225.0
# 	392.0
#
# ID: 48618
#   → Column 'number_of_searches' differs: [np.float64(341.0), np.float64(885.0)]
# 	341.0
# 	885.0
#
# ID: 48958
#   → Column 'number_of_searches' differs: [np.float64(129.0), np.float64(1217.0), np.float64(2.0)]
# 	129.0
# 	1217.0
# 	2.0
#
# ID: 49172
#   → Column 'number_of_searches' differs: [np.float64(758.0), np.float64(2.0)]
# 	758.0
# 	2.0
#
# ID: 49643
#   → Column 'number_of_searches' differs: [np.float64(839.0), np.float64(652.0)]
# 	839.0
# 	652.0
#
# ID: 49692
#   → Column 'number_of_searches' differs: [np.float64(951.0), np.float64(901.0), np.float64(414.0), np.float64(950.0)]
# 	951.0
# 	901.0
# 	414.0
# 	950.0
#
# ID: 49795
#   → Column 'number_of_searches' differs: [np.float64(507.0), np.float64(506.0)]
# 	507.0
# 	506.0
#
# ID: 50029
#   → Column 'number_of_searches' differs: [np.float64(16.0), np.float64(45.0), np.float64(131.0)]
# 	16.0
# 	45.0
# 	131.0
#
# ID: 50041
#   → Column 'number_of_searches' differs: [np.float64(1459.0), np.float64(1330.0)]
# 	1459.0
# 	1330.0
#
# ID: 50148
#   → Column 'number_of_searches' differs: [np.float64(699.0), np.float64(1194.0)]
# 	699.0
# 	1194.0
#
# ID: 50581
#   → Column 'number_of_searches' differs: [np.float64(499.0), np.float64(381.0)]
# 	499.0
# 	381.0
#
# ID: 50935
#   → Column 'Last Role' differs: ['procurement specialist buyer', 'training member – system analyst engineer']
#   → Column 'number_of_searches' differs: [np.float64(905.0), np.float64(887.0), np.float64(1148.0)]
# 	905.0
# 	887.0
# 	1148.0
#
# ID: 51081
#   → Column 'number_of_searches' differs: [np.float64(1037.0), np.float64(933.0)]
# 	1037.0
# 	933.0
#
# ID: 51141
#   → Column 'number_of_searches' differs: [np.float64(48.0), np.float64(588.0)]
# 	48.0
# 	588.0
#
# ID: 51460
#   → Column 'number_of_searches' differs: [np.float64(1472.0), np.float64(1409.0)]
# 	1472.0
# 	1409.0
#
# ID: 51570
#   → Column 'number_of_searches' differs: [np.float64(166.0), np.float64(258.0)]
# 	166.0
# 	258.0
#
# ID: 51978
#   → Column 'number_of_searches' differs: [np.float64(366.0), np.float64(1214.0)]
# 	366.0
# 	1214.0
#
# ID: 52096
#   → Column 'number_of_searches' differs: [np.float64(654.0), np.float64(878.0)]
# 	654.0
# 	878.0
#
# ID: 53464
#   → Column 'number_of_searches' differs: [np.float64(81.0), np.float64(394.0)]
# 	81.0
# 	394.0
#
# ID: 54795
#   → Column 'number_of_searches' differs: [np.float64(1282.0), np.float64(367.0)]
# 	1282.0
# 	367.0
#
# ID: 54884
#   → Column 'number_of_searches' differs: [np.float64(1154.0), np.float64(1128.0)]
# 	1154.0
# 	1128.0
#
# ID: 55032
#   → Column 'number_of_searches' differs: [np.float64(1040.0), np.float64(1283.0), np.float64(866.0)]
# 	1040.0
# 	1283.0
# 	866.0
#
# ID: 55094
#   → Column 'number_of_searches' differs: [np.float64(195.0), np.float64(589.0), np.float64(453.0)]
# 	195.0
# 	589.0
# 	453.0
#
# ID: 55405
#   → Column 'number_of_searches' differs: [np.float64(903.0), np.float64(35.0)]
# 	903.0
# 	35.0
#
# ID: 55452
#   → Column 'number_of_searches' differs: [np.float64(1195.0), np.float64(215.0)]
# 	1195.0
# 	215.0
#
# ID: 55709
#   → Column 'number_of_searches' differs: [np.float64(35.0), np.float64(913.0)]
# 	35.0
# 	913.0
#
# ID: 56081
#   → Column 'number_of_searches' differs: [np.float64(445.0), np.float64(35.0)]
# 	445.0
# 	35.0
#
# ID: 56566
#   → Column 'number_of_searches' differs: [np.float64(37.0), np.float64(960.0)]
# 	37.0
# 	960.0
#
# ID: 56651
#   → Column 'number_of_searches' differs: [np.float64(99.0), np.float64(1066.0), np.float64(1310.0)]
# 	99.0
# 	1066.0
# 	1310.0
#
# ID: 56764
#   → Column 'number_of_searches' differs: [np.float64(764.0), np.float64(837.0)]
# 	764.0
# 	837.0
#
# ID: 57918
#   → Column 'number_of_searches' differs: [np.float64(414.0), np.float64(195.0)]
# 	414.0
# 	195.0
#
# ID: 58053
#   → Column 'number_of_searches' differs: [np.float64(228.0), np.float64(1324.0), np.float64(1321.0)]
# 	228.0
# 	1324.0
# 	1321.0
#
# ID: 58057
#   → Column 'number_of_searches' differs: [np.float64(615.0), np.float64(490.0)]
# 	615.0
# 	490.0
#
# ID: 58310
#   → Column 'number_of_searches' differs: [np.float64(12.0), np.float64(631.0)]
# 	12.0
# 	631.0
#
# ID: 58907
#   → Column 'number_of_searches' differs: [np.float64(453.0), np.float64(589.0)]
# 	453.0
# 	589.0
#
# ID: 58984
#   → Column 'number_of_searches' differs: [np.float64(125.0), np.float64(466.0)]
# 	125.0
# 	466.0
#
# ID: 59626
#   → Column 'number_of_searches' differs: [np.float64(30.0), np.float64(798.0)]
# 	30.0
# 	798.0
#
# ID: 60292
#   → Column 'number_of_searches' differs: [np.float64(135.0), np.float64(184.0), np.float64(219.0)]
# 	135.0
# 	184.0
# 	219.0
#
# ID: 60340
#   → Column 'number_of_searches' differs: [np.float64(876.0), np.float64(905.0)]
# 	876.0
# 	905.0
#
# ID: 60860
#   → Column 'number_of_searches' differs: [np.float64(499.0), np.float64(882.0)]
# 	499.0
# 	882.0
#
# ID: 60948
#   → Column 'number_of_searches' differs: [np.float64(386.0), np.float64(501.0)]
# 	386.0
# 	501.0
#
# ID: 61113
#   → Column 'number_of_searches' differs: [np.float64(590.0), np.float64(160.0)]
# 	590.0
# 	160.0
#
# ID: 61908
#   → Column 'number_of_searches' differs: [np.float64(637.0), np.float64(622.0)]
# 	637.0
# 	622.0
#
# ID: 62240
#   → Column 'number_of_searches' differs: [np.float64(1248.0), np.float64(191.0), np.float64(242.0)]
# 	1248.0
# 	191.0
# 	242.0
#
# ID: 62267
#   → Column 'number_of_searches' differs: [np.float64(705.0), np.float64(165.0)]
# 	705.0
# 	165.0
#
# ID: 62766
#   → Column 'number_of_searches' differs: [np.float64(219.0), np.float64(1186.0)]
# 	219.0
# 	1186.0
#
# ID: 62894
#   → Column 'number_of_searches' differs: [np.float64(782.0), np.float64(532.0)]
# 	782.0
# 	532.0
#
# ID: 63213
#   → Column 'number_of_searches' differs: [np.float64(480.0), np.float64(557.0)]
# 	480.0
# 	557.0
#
# ID: 63565
#   → Column 'number_of_searches' differs: [np.float64(768.0), np.float64(1144.0)]
# 	768.0
# 	1144.0
#
# ID: 63953
#   → Column 'number_of_searches' differs: [np.float64(287.0), np.float64(675.0)]
# 	287.0
# 	675.0
#
# ID: 64021
#   → Column 'number_of_searches' differs: [np.float64(1522.0), np.float64(640.0)]
# 	1522.0
# 	640.0
#
# ID: 64113
#   → Column 'number_of_searches' differs: [np.float64(737.0), np.float64(174.0), np.float64(944.0)]
# 	737.0
# 	174.0
# 	944.0
#
# ID: 64130
#   → Column 'number_of_searches' differs: [np.float64(338.0), np.float64(1278.0)]
# 	338.0
# 	1278.0
#
# ID: 64151
#   → Column 'number_of_searches' differs: [np.float64(130.0), np.float64(616.0)]
# 	130.0
# 	616.0
#
# ID: 64545
#   → Column 'number_of_searches' differs: [np.float64(876.0), np.float64(367.0)]
# 	876.0
# 	367.0
#
# ID: 64621
#   → Column 'number_of_searches' differs: [np.float64(728.0), np.float64(1163.0)]
# 	728.0
# 	1163.0
#
# ID: 64832
#   → Column 'number_of_searches' differs: [np.float64(785.0), np.float64(412.0)]
# 	785.0
# 	412.0
#
# ID: 65036
#   → Column 'number_of_searches' differs: [np.float64(1231.0), np.float64(162.0)]
# 	1231.0
# 	162.0
#
# ID: 65479
#   → Column 'number_of_searches' differs: [np.float64(354.0), np.float64(972.0)]
# 	354.0
# 	972.0
#
# ID: 65558
#   → Column 'number_of_searches' differs: [np.float64(221.0), np.float64(145.0), np.float64(45.0)]
# 	221.0
# 	145.0
# 	45.0
#
# ID: 65578
#   → Column 'number_of_searches' differs: [np.float64(325.0), np.float64(195.0)]
# 	325.0
# 	195.0
#
# ID: 66051
#   → Column 'number_of_searches' differs: [np.float64(830.0), np.float64(28.0)]
# 	830.0
# 	28.0
#
# ID: 66058
#   → Column 'number_of_searches' differs: [np.float64(65.0), np.float64(264.0)]
# 	65.0
# 	264.0
#
# ID: 66132
#   → Column 'number_of_searches' differs: [np.float64(544.0), np.float64(226.0)]
# 	544.0
# 	226.0
#
# ID: 66425
#   → Column 'number_of_searches' differs: [np.float64(1170.0), np.float64(785.0)]
# 	1170.0
# 	785.0
#
# ID: 66718
#   → Column 'number_of_searches' differs: [np.float64(450.0), np.float64(532.0)]
# 	450.0
# 	532.0
#
# ID: 66795
#   → Column 'number_of_searches' differs: [np.float64(187.0), np.float64(56.0)]
# 	187.0
# 	56.0
#
# ID: 66818
#   → Column 'number_of_searches' differs: [np.float64(695.0), np.float64(626.0)]
# 	695.0
# 	626.0
#
# ID: 67288
#   → Column 'number_of_searches' differs: [np.float64(7.0), np.float64(1614.0)]
# 	7.0
# 	1614.0
#
# ID: 67376
#   → Column 'number_of_searches' differs: [np.float64(1711.0), np.float64(667.0)]
# 	1711.0
# 	667.0
#
# ID: 67654
#   → Column 'number_of_searches' differs: [np.float64(228.0), np.float64(751.0)]
# 	228.0
# 	751.0
#
# ID: 67831
#   → Column 'Job Family Hiring' differs: ['Support', 'Enabling Function']
# 	Support
# 	Enabling Function
#
# ID: 68008
#   → Column 'number_of_searches' differs: [np.float64(230.0), np.float64(985.0)]
# 	230.0
# 	985.0
#
# ID: 68028
#   → Column 'number_of_searches' differs: [np.float64(255.0), np.float64(600.0), np.float64(228.0), np.float64(385.0), np.float64(504.0)]
# 	255.0
# 	600.0
# 	228.0
# 	385.0
# 	504.0
#
# ID: 68155
#   → Column 'number_of_searches' differs: [np.float64(888.0), np.float64(310.0), np.float64(793.0)]
# 	888.0
# 	310.0
# 	793.0
#
# ID: 68204
#   → Column 'number_of_searches' differs: [np.float64(933.0), np.float64(1037.0)]
# 	933.0
# 	1037.0
#
# ID: 68231
#   → Column 'number_of_searches' differs: [np.float64(554.0), np.float64(1125.0)]
# 	554.0
# 	1125.0
#
# ID: 68334
#   → Column 'number_of_searches' differs: [np.float64(235.0), np.float64(36.0), np.float64(382.0)]
# 	235.0
# 	36.0
# 	382.0
#
# ID: 68659
#   → Column 'number_of_searches' differs: [np.float64(950.0), np.float64(785.0)]
# 	950.0
# 	785.0
#
# ID: 68705
#   → Column 'number_of_searches' differs: [np.float64(766.0), np.float64(1036.0)]
# 	766.0
# 	1036.0
#
# ID: 68821
#   → Column 'number_of_searches' differs: [np.float64(404.0), np.float64(787.0)]
# 	404.0
# 	787.0
#
# ID: 68900
#   → Column 'number_of_searches' differs: [np.float64(811.0), np.float64(232.0)]
# 	811.0
# 	232.0
#
# ID: 69206
#   → Column 'number_of_searches' differs: [np.float64(884.0), np.float64(433.0), np.float64(667.0)]
# 	884.0
# 	433.0
# 	667.0
#
# ID: 69220
#   → Column 'number_of_searches' differs: [np.float64(724.0), np.float64(354.0), np.float64(631.0), np.float64(555.0)]
# 	724.0
# 	354.0
# 	631.0
# 	555.0
#
# ID: 69363
#   → Column 'number_of_searches' differs: [np.float64(78.0), np.float64(881.0)]
# 	78.0
# 	881.0
#
# ID: 69393
#   → Column 'number_of_searches' differs: [np.float64(193.0), np.float64(128.0)]
# 	193.0
# 	128.0
#
# ID: 69852
#   → Column 'number_of_searches' differs: [np.float64(463.0), np.float64(484.0), np.float64(783.0)]
# 	463.0
# 	484.0
# 	783.0
#
# ID: 70026
#   → Column 'number_of_searches' differs: [np.float64(401.0), np.float64(10.0)]
# 	401.0
# 	10.0
#
# ID: 70051
#   → Column 'number_of_searches' differs: [np.float64(952.0), np.float64(1329.0)]
# 	952.0
# 	1329.0
#
# ID: 70267
#   → Column 'number_of_searches' differs: [np.float64(313.0), np.float64(119.0)]
# 	313.0
# 	119.0
#
# ID: 70283
#   → Column 'number_of_searches' differs: [np.float64(728.0), np.float64(243.0)]
# 	728.0
# 	243.0
#
# ID: 70642
#   → Column 'number_of_searches' differs: [np.float64(1151.0), np.float64(699.0), np.float64(991.0), np.float64(647.0)]
# 	1151.0
# 	699.0
# 	991.0
# 	647.0
#
# ID: 70845
#   → Column 'number_of_searches' differs: [np.float64(258.0), np.float64(724.0)]
# 	258.0
# 	724.0
#
# ID: 71052
#   → Column 'number_of_searches' differs: [np.float64(160.0), np.float64(1010.0)]
# 	160.0
# 	1010.0
#
# ID: 71295
#   → Column 'number_of_searches' differs: [np.float64(1130.0), np.float64(420.0), np.float64(694.0), np.float64(763.0)]
# 	1130.0
# 	420.0
# 	694.0
# 	763.0
#
# ID: 71386
#   → Column 'number_of_searches' differs: [np.float64(141.0), np.float64(965.0)]
# 	141.0
# 	965.0
#
# ID: 71459
#   → Column 'number_of_searches' differs: [np.float64(341.0), np.float64(630.0)]
# 	341.0
# 	630.0
#
# ID: 71470
#   → Column 'number_of_searches' differs: [np.float64(145.0), np.float64(114.0), np.float64(26.0)]
# 	145.0
# 	114.0
# 	26.0
#
# ID: 71602
#   → Column 'number_of_searches' differs: [np.float64(541.0), np.float64(677.0)]
# 	541.0
# 	677.0
#
# ID: 71736
#   → Column 'number_of_searches' differs: [np.float64(243.0), np.float64(394.0)]
# 	243.0
# 	394.0
#
# ID: 72176
#   → Column 'number_of_searches' differs: [np.float64(276.0), np.float64(839.0)]
# 	276.0
# 	839.0
#
# ID: 72671
#   → Column 'number_of_searches' differs: [np.float64(314.0), np.float64(383.0)]
# 	314.0
# 	383.0
#
# ID: 72892
#   → Column 'number_of_searches' differs: [np.float64(777.0), np.float64(642.0), np.float64(352.0)]
# 	777.0
# 	642.0
# 	352.0
#
# ID: 72968
#   → Column 'number_of_searches' differs: [np.float64(1556.0), np.float64(1555.0)]
# 	1556.0
# 	1555.0
#
# ID: 73886
#   → Column 'number_of_searches' differs: [np.float64(951.0), np.float64(950.0)]
# 	951.0
# 	950.0
#
# ID: 73983
#   → Column 'number_of_searches' differs: [np.float64(119.0), np.float64(243.0)]
# 	119.0
# 	243.0
#
# ID: 74241
#   → Column 'number_of_searches' differs: [np.float64(440.0), np.float64(215.0)]
# 	440.0
# 	215.0
#
# ID: 74311
#   → Column 'number_of_searches' differs: [np.float64(986.0), np.float64(1083.0)]
# 	986.0
# 	1083.0
#
# ID: 74429
#   → Column 'number_of_searches' differs: [np.float64(1262.0), np.float64(93.0)]
# 	1262.0
# 	93.0
#
# ID: 74607
#   → Column 'number_of_searches' differs: [np.float64(641.0), np.float64(789.0), np.float64(229.0)]
# 	641.0
# 	789.0
# 	229.0
#
# ID: 74627
#   → Column 'number_of_searches' differs: [np.float64(308.0), np.float64(1048.0)]
# 	308.0
# 	1048.0
#
# ID: 74701
#   → Column 'number_of_searches' differs: [np.float64(554.0), np.float64(93.0)]
# 	554.0
# 	93.0
#
# ID: 74817
#   → Column 'number_of_searches' differs: [np.float64(684.0), np.float64(1281.0), np.float64(420.0), np.float64(218.0)]
# 	684.0
# 	1281.0
# 	420.0
# 	218.0
#
# ID: 75155
#   → Column 'number_of_searches' differs: [np.float64(951.0), np.float64(327.0), np.float64(1160.0), np.float64(125.0)]
# 	951.0
# 	327.0
# 	1160.0
# 	125.0
#
# ID: 75187
#   → Column 'number_of_searches' differs: [np.float64(781.0), np.float64(610.0)]
# 	781.0
# 	610.0
#
# ID: 75314
#   → Column 'number_of_searches' differs: [np.float64(744.0), np.float64(764.0)]
# 	744.0
# 	764.0
#
# ID: 75522
#   → Column 'number_of_searches' differs: [np.float64(354.0), np.float64(48.0)]
# 	354.0
# 	48.0
#
# ID: 75646
#   → Column 'number_of_searches' differs: [np.float64(581.0), np.float64(1129.0)]
# 	581.0
# 	1129.0
#
# ID: 76216
#   → Column 'number_of_searches' differs: [np.float64(478.0), np.float64(744.0), np.float64(1283.0), np.float64(650.0), np.float64(158.0)]
# 	478.0
# 	744.0
# 	1283.0
# 	650.0
# 	158.0
#
# ID: 76247
#   → Column 'number_of_searches' differs: [np.float64(555.0), np.float64(288.0)]
# 	555.0
# 	288.0
#
# ID: 76385
#   → Column 'number_of_searches' differs: [np.float64(184.0), np.float64(903.0)]
# 	184.0
# 	903.0
#
# ID: 76570
#   → Column 'number_of_searches' differs: [np.float64(319.0), np.float64(414.0)]
# 	319.0
# 	414.0
#
# ID: 76638
#   → Column 'number_of_searches' differs: [np.float64(749.0), np.float64(758.0), np.float64(157.0)]
# 	749.0
# 	758.0
# 	157.0
#
# ID: 76752
#   → Column 'Last Role' differs: ['analyst of logistics', 'metalworker tester']
# 	analyst of logistics
# 	metalworker tester
#
# ID: 76854
#   → Column 'number_of_searches' differs: [np.float64(299.0), np.float64(480.0), np.float64(206.0)]
# 	299.0
# 	480.0
# 	206.0
#
# ID: 77438
#   → Column 'number_of_searches' differs: [np.float64(1064.0), np.float64(958.0)]
# 	1064.0
# 	958.0
#
# ID: 77640
#   → Column 'number_of_searches' differs: [np.float64(13.0), np.float64(490.0)]
# 	13.0
# 	490.0
#
# ID: 77890
#   → Column 'number_of_searches' differs: [np.float64(193.0), np.float64(354.0), np.float64(48.0)]
# 	193.0
# 	354.0
# 	48.0
#
# ID: 78419
#   → Column 'number_of_searches' differs: [np.float64(781.0), np.float64(705.0), np.float64(622.0)]
# 	781.0
# 	705.0
# 	622.0
#
# ID: 78530
#   → Column 'number_of_searches' differs: [np.float64(876.0), np.float64(750.0)]
# 	876.0
# 	750.0
#
# ID: 78992
#   → Column 'number_of_searches' differs: [np.float64(224.0), np.float64(284.0)]
# 	224.0
# 	284.0
#
# ID: 79008
#   → Column 'number_of_searches' differs: [np.float64(119.0), np.float64(397.0)]
# 	119.0
# 	397.0
#
# ID: 79043
#   → Column 'number_of_searches' differs: [np.float64(198.0), np.float64(298.0)]
# 	198.0
# 	298.0
#
# ID: 79641
#   → Column 'number_of_searches' differs: [np.float64(861.0), np.float64(159.0)]
# 	861.0
# 	159.0
#
# ID: 79760
#   → Column 'number_of_searches' differs: [np.float64(991.0), np.float64(905.0)]
# 	991.0
# 	905.0
#
# ID: 79894
#   → Column 'number_of_searches' differs: [np.float64(700.0), np.float64(402.0)]
# 	700.0
# 	402.0
#
# ID: 80229
#   → Column 'number_of_searches' differs: [np.float64(1120.0), np.float64(933.0)]
# 	1120.0
# 	933.0
#
# ID: 80278
#   → Column 'number_of_searches' differs: [np.float64(210.0), np.float64(93.0)]
# 	210.0
# 	93.0
#
# ID: 80495
#   → Column 'number_of_searches' differs: [np.float64(564.0), np.float64(536.0)]
# 	564.0
# 	536.0
#
# ID: 80568
#   → Column 'number_of_searches' differs: [np.float64(367.0), np.float64(109.0)]
# 	367.0
# 	109.0
#
# ID: 80927
#   → Column 'number_of_searches' differs: [np.float64(291.0), np.float64(259.0)]
# 	291.0
# 	259.0
#
# ID: 81510
#   → Column 'number_of_searches' differs: [np.float64(320.0), np.float64(1006.0)]
# 	320.0
# 	1006.0
#
# ID: 10895_1
#   → Column 'number_of_searches' differs: [np.float64(722.0), np.float64(1147.0)]
# 	722.0
# 	1147.0
#
# ID: 11829_2
#   → Column 'number_of_searches' differs: [np.float64(732.0), np.float64(584.0)]
# 	732.0
# 	584.0
#
# ID: 13463_1
#   → Column 'number_of_searches' differs: [np.float64(256.0), np.float64(480.0)]
# 	256.0
# 	480.0
#
# ID: 13744_1
#   → Column 'number_of_searches' differs: [np.float64(644.0), np.float64(901.0), np.float64(386.0)]
# 	644.0
# 	901.0
# 	386.0
#
# ID: 15950_1
#   → Column 'number_of_searches' differs: [np.float64(885.0), np.float64(590.0)]
# 	885.0
# 	590.0
#
# ID: 16536_1
#   → Column 'number_of_searches' differs: [np.float64(1125.0), np.float64(959.0)]
# 	1125.0
# 	959.0
#
# ID: 1903_1
#   → Column 'number_of_searches' differs: [np.float64(135.0), np.float64(1138.0)]
# 	135.0
# 	1138.0
#
# ID: 21228_1
#   → Column 'number_of_searches' differs: [np.float64(787.0), np.float64(1047.0), np.float64(110.0)]
# 	787.0
# 	1047.0
# 	110.0
#
# ID: 21350_1
#   → Column 'number_of_searches' differs: [np.float64(880.0), np.float64(325.0)]
# 	880.0
# 	325.0
#
# ID: 21599_1
#   → Column 'number_of_searches' differs: [np.float64(699.0), np.float64(819.0)]
# 	699.0
# 	819.0
#
# ID: 22025_2
#   → Column 'Candidate Profile' differs: ['curricular internships', 'curricular internships for maserati pwt customer']
# 	curricular internships
# 	curricular internships for maserati pwt customer
#
# ID: 22075_1
#   → Column 'number_of_searches' differs: [np.float64(1254.0), np.float64(427.0), np.float64(1154.0)]
# 	1254.0
# 	427.0
# 	1154.0
#
# ID: 22886_2
#   → Column 'number_of_searches' differs: [np.float64(526.0), np.float64(1250.0)]
# 	526.0
# 	1250.0
#
# ID: 24216_2
#   → Column 'number_of_searches' differs: [np.float64(1274.0), np.float64(180.0)]
# 	1274.0
# 	180.0
#
# ID: 28061_2
#   → Column 'number_of_searches' differs: [np.float64(524.0), np.float64(564.0)]
# 	524.0
# 	564.0
#
# ID: 28587_1
#   → Column 'number_of_searches' differs: [np.float64(430.0), np.float64(13.0)]
# 	430.0
# 	13.0
#
# ID: 28587_2
#   → Column 'number_of_searches' differs: [np.float64(430.0), np.float64(13.0)]
# 	430.0
# 	13.0
#
# ID: 28658_1
#   → Column 'number_of_searches' differs: [np.float64(191.0), np.float64(1272.0), np.float64(863.0)]
# 	191.0
# 	1272.0
# 	863.0
#
# ID: 28734_1
#   → Column 'number_of_searches' differs: [np.float64(787.0), np.float64(139.0), np.float64(524.0)]
# 	787.0
# 	139.0
# 	524.0
#
# ID: 28734_2
#   → Column 'number_of_searches' differs: [np.float64(787.0), np.float64(139.0), np.float64(524.0)]
# 	787.0
# 	139.0
# 	524.0
#
# ID: 28741_3
#   → Column 'number_of_searches' differs: [np.float64(566.0), np.float64(1323.0), np.float64(1234.0)]
# 	566.0
# 	1323.0
# 	1234.0
#
# ID: 31595_1
#   → Column 'number_of_searches' differs: [np.float64(1001.0), np.float64(595.0)]
# 	1001.0
# 	595.0
#
# ID: 33269_2
#   → Column 'number_of_searches' differs: [np.float64(450.0), np.float64(532.0)]
# 	450.0
# 	532.0
#
# ID: 34730_2
#   → Column 'number_of_searches' differs: [np.float64(905.0), np.float64(627.0)]
# 	905.0
# 	627.0
#
# ID: 3510_2
#   → Column 'number_of_searches' differs: [np.float64(960.0), np.float64(1387.0)]
# 	960.0
# 	1387.0
#
# ID: 37299_1
#   → Column 'number_of_searches' differs: [np.float64(160.0), np.float64(14.0), np.float64(335.0)]
# 	160.0
# 	14.0
# 	335.0
#
# ID: 38616_1
#   → Column 'number_of_searches' differs: [np.float64(180.0), np.float64(178.0), np.float64(649.0), np.float64(405.0)]
# 	180.0
# 	178.0
# 	649.0
# 	405.0
#
# ID: 38616_2
#   → Column 'number_of_searches' differs: [np.float64(180.0), np.float64(178.0), np.float64(649.0), np.float64(405.0)]
# 	180.0
# 	178.0
# 	649.0
# 	405.0
#
# ID: 39576_2
#   → Column 'number_of_searches' differs: [np.float64(11.0), np.float64(1175.0)]
# 	11.0
# 	1175.0
#
# ID: 40226_2
#   → Column 'number_of_searches' differs: [np.float64(857.0), np.float64(1610.0)]
# 	857.0
# 	1610.0
#
# ID: 41269_1
#   → Column 'number_of_searches' differs: [np.float64(318.0), np.float64(66.0)]
# 	318.0
# 	66.0
#
# ID: 41479_1
#   → Column 'number_of_searches' differs: [np.float64(1118.0), np.float64(1154.0)]
# 	1118.0
# 	1154.0
#
# ID: 42598_1
#   → Column 'number_of_searches' differs: [np.float64(171.0), np.float64(916.0)]
# 	171.0
# 	916.0
#
# ID: 42598_2
#   → Column 'number_of_searches' differs: [np.float64(171.0), np.float64(916.0)]
# 	171.0
# 	916.0
#
# ID: 43477_3
#   → Column 'number_of_searches' differs: [np.float64(532.0), np.float64(782.0)]
# 	532.0
# 	782.0
#
# ID: 44679_1
#   → Column 'number_of_searches' differs: [np.float64(450.0), np.float64(532.0), np.float64(933.0)]
# 	450.0
# 	532.0
# 	933.0
#
# ID: 47142_1
#   → Column 'number_of_searches' differs: [np.float64(117.0), np.float64(412.0)]
# 	117.0
# 	412.0
#
# ID: 49368_1
#   → Column 'number_of_searches' differs: [np.float64(879.0), np.float64(689.0)]
# 	879.0
# 	689.0
#
# ID: 49368_2
#   → Column 'number_of_searches' differs: [np.float64(622.0), np.float64(99.0)]
# 	622.0
# 	99.0
#
# ID: 50448_1
#   → Column 'number_of_searches' differs: [np.float64(350.0), np.float64(36.0)]
# 	350.0
# 	36.0
#
# ID: 5065_1
#   → Column 'number_of_searches' differs: [np.float64(263.0), np.float64(785.0)]
# 	263.0
# 	785.0
#
# ID: 50771_1
#   → Column 'number_of_searches' differs: [np.float64(232.0), np.float64(150.0)]
# 	232.0
# 	150.0
#
# ID: 52238_1
#   → Column 'number_of_searches' differs: [np.float64(1144.0), np.float64(354.0)]
# 	1144.0
# 	354.0
#
# ID: 5538_1
#   → Column 'number_of_searches' differs: [np.float64(109.0), np.float64(450.0)]
# 	109.0
# 	450.0
#
# ID: 5791_1
#   → Column 'number_of_searches' differs: [np.float64(647.0), np.float64(1082.0)]
# 	647.0
# 	1082.0
#
# ID: 58007_1
#   → Column 'number_of_searches' differs: [np.float64(16.0), np.float64(25.0), np.float64(832.0)]
# 	16.0
# 	25.0
# 	832.0
#
# ID: 58834_1
#   → Column 'number_of_searches' differs: [np.float64(964.0), np.float64(266.0)]
# 	964.0
# 	266.0
#
# ID: 59756_2
#   → Column 'number_of_searches' differs: [np.float64(195.0), np.float64(581.0)]
# 	195.0
# 	581.0
#
# ID: 6333_2
#   → Column 'number_of_searches' differs: [np.float64(243.0), np.float64(354.0)]
# 	243.0
# 	354.0
#
# ID: 6353_1
#   → Column 'number_of_searches' differs: [np.float64(31.0), np.float64(108.0), np.float64(93.0), np.float64(53.0)]
# 	31.0
# 	108.0
# 	93.0
# 	53.0
#
# ID: 66932_1
#   → Column 'number_of_searches' differs: [np.float64(230.0), np.float64(1200.0)]
# 	230.0
# 	1200.0
#
# ID: 67836_2
#   → Column 'number_of_searches' differs: [np.float64(1688.0), np.float64(1027.0), np.float64(45.0)]
# 	1688.0
# 	1027.0
# 	45.0
#
# ID: 68643_1
#   → Column 'number_of_searches' differs: [np.float64(739.0), np.float64(1319.0)]
# 	739.0
# 	1319.0
#
# ID: 69473_2
#   → Column 'number_of_searches' differs: [np.float64(1329.0), np.float64(952.0), np.float64(201.0)]
# 	1329.0
# 	952.0
# 	201.0
#
# ID: 7162_1
#   → Column 'number_of_searches' differs: [np.float64(141.0), np.float64(937.0), np.float64(1580.0), np.float64(1184.0), np.float64(1207.0)]
# 	141.0
# 	937.0
# 	1580.0
# 	1184.0
# 	1207.0
#
# ID: 731_2
#   → Column 'number_of_searches' differs: [np.float64(860.0), np.float64(901.0), np.float64(1094.0), np.float64(254.0), np.float64(687.0)]
# 	860.0
# 	901.0
# 	1094.0
# 	254.0
# 	687.0
#
# ID: 73997_1
#   → Column 'number_of_searches' differs: [np.float64(190.0), np.float64(354.0)]
# 	190.0
# 	354.0
#
# ID: 73997_2
#   → Column 'number_of_searches' differs: [np.float64(190.0), np.float64(354.0)]
# 	190.0
# 	354.0
#
# ID: 74789_1
#   → Column 'number_of_searches' differs: [np.float64(712.0), np.float64(160.0)]
# 	712.0
# 	160.0
#
# ID: 78011_2
#   → Column 'number_of_searches' differs: [np.float64(1062.0), np.float64(759.0)]
# 	1062.0
# 	759.0
#
# ID: 79489_1
#   → Column 'number_of_searches' differs: [np.float64(370.0), np.float64(654.0)]
# 	370.0
# 	654.0
#
# ID: 80338_2
#   → Column 'number_of_searches' differs: [np.float64(1453.0), np.float64(1005.0)]
# 	1453.0
# 	1005.0
#
# ID: 9585_1
#   → Column 'number_of_searches' differs: [np.float64(224.0), np.float64(236.0), np.float64(1250.0)]
# 	224.0
# 	236.0
# 	1250.0

# %%
import numpy as np
def aggregate_group(group):
    for col in group.columns:
        if col == 'ID':
            continue  
        values = group[col].dropna().unique()
        if len(values) == 0:
            continue 
        elif len(values) == 1:
            group[col] = values[0]
        else:
            if np.issubdtype(group[col].dropna().dtype, np.number):
                avg_value = group[col].dropna().astype(float).mean()
                group[col] = avg_value
            else:
                string_values = [str(v).strip() for v in values]
                filtered_values = [v for v in string_values if v]
                combined_string = "|".join(str(v) for v in filtered_values)
                group[col] = combined_string
    return group

def aggregate_all_records(df):
    df_cleaned = df.drop(columns=['event_feedback', 'event_type__val']).drop_duplicates().reset_index(drop=True)

    grouped = df_cleaned.groupby('ID')

    groups_with_multiple = grouped.filter(lambda x: len(x) > 1)

    fixed_groups = groups_with_multiple.groupby('ID', group_keys=False).apply(aggregate_group).drop_duplicates().reset_index(drop=True)
    groups_with_single = grouped.filter(lambda x: len(x) == 1)
    final_df = pd.concat([fixed_groups, groups_with_single], ignore_index=True)

    print(f"Original number of records: {len(df['ID'])}")
    print(f"Aggregated number of records: {len(final_df['ID'])}")
    return final_df


final_df = aggregate_all_records(df)
# Out:
# Original number of records: 8990
# Aggregated number of records: 4870

# %%
def clean_piped_string(val):
    if isinstance(val, str) and '|' in val:
        parts = val.split('|')
        filtered_parts = [p.strip() for p in parts if p.strip()]

        if not filtered_parts:
            return '' 
        elif len(filtered_parts) == 1:
            return filtered_parts[0]
        else:
            return '|'.join(filtered_parts)
    else:
        return val

def clean_all_piped_entries(df):

    df_cleaned = df.copy() 
    string_cols = df_cleaned.select_dtypes(include=['object', 'string']).columns

    print(f"Applying cleaning to columns: {list(string_cols)}")

    for col in string_cols:
        df_cleaned[col] = df_cleaned[col].map(clean_piped_string, na_action='ignore')

    print("Cleaning complete.")
    return df_cleaned
final_df = clean_all_piped_entries(final_df)
# Out:
# Applying cleaning to columns: ['ID', 'Candidate State', 'Age Range', 'Residence', 'Sex', 'TAG', 'Study area', 'Study Title', 'Years Experience', 'Sector', 'Last Role', 'Year of insertion', 'Recruitment Request', 'Assumption Headquarters', 'Job Family Hiring', 'Job Title Hiring', 'Job Description', 'Candidate Profile', 'Years Experience.1', 'Study Level', 'Study Area.1', 'Akkodis headquarters']
# Cleaning complete.

# %%
def print_pipe_entries(df):
    for idx, row in df.iterrows():
        for col in df.columns:
            val = row[col]
            if isinstance(val, str) and '|' in val:
                print(f"Column: {col}, Row ID: {idx}, Value: {val}")
                print(val.split('|'))
                print([v.strip() for v in val.split('|') if v.strip()])
print_pipe_entries(final_df)
# Out:
# Column: Candidate Profile, Row ID: 257, Value: excellent references for product/subsystem v&v activities for the railway sector excellent references in conducting product/system validation/integration test activities good knowledge of the alstom v&v process good knowledge of the functionality of tms systems knowledge is appreciated of products good familiarity with laboratory testing activities (in particular for functional tests on targets)|excellent references for product/subsystem v&v activities for the railway sector excellent references in conducting product/system validation/integration test activities good knowledge of the alstom v&v process good knowledge of the functionality of tms systems knowledge is appreciated of alstom products good familiarity with laboratory testing activities (in particular for functional tests on targets)
# ['excellent references for product/subsystem v&v activities for the railway sector excellent references in conducting product/system validation/integration test activities good knowledge of the alstom v&v process good knowledge of the functionality of tms systems knowledge is appreciated of products good familiarity with laboratory testing activities (in particular for functional tests on targets)', 'excellent references for product/subsystem v&v activities for the railway sector excellent references in conducting product/system validation/integration test activities good knowledge of the alstom v&v process good knowledge of the functionality of tms systems knowledge is appreciated of alstom products good familiarity with laboratory testing activities (in particular for functional tests on targets)']
# ['excellent references for product/subsystem v&v activities for the railway sector excellent references in conducting product/system validation/integration test activities good knowledge of the alstom v&v process good knowledge of the functionality of tms systems knowledge is appreciated of products good familiarity with laboratory testing activities (in particular for functional tests on targets)', 'excellent references for product/subsystem v&v activities for the railway sector excellent references in conducting product/system validation/integration test activities good knowledge of the alstom v&v process good knowledge of the functionality of tms systems knowledge is appreciated of alstom products good familiarity with laboratory testing activities (in particular for functional tests on targets)']
# Column: Job Family Hiring, Row ID: 300, Value: Support|Enabling Function
# ['Support', 'Enabling Function']
# ['Support', 'Enabling Function']
# Column: Job Description, Row ID: 541, Value: for procurement activities with clients, it is essential to have a living room populated with buyers of medium experience for the activities we foresee in the coming weeks/months. focus on buyers relating to materials (of all disciplines)|for procurement activities withclients, it is essential to have a living room populated with buyers of medium experience for the activities we foresee in the coming weeks/months. focus on buyers relating to materials (of all disciplines)
# ['for procurement activities with clients, it is essential to have a living room populated with buyers of medium experience for the activities we foresee in the coming weeks/months. focus on buyers relating to materials (of all disciplines)', 'for procurement activities withclients, it is essential to have a living room populated with buyers of medium experience for the activities we foresee in the coming weeks/months. focus on buyers relating to materials (of all disciplines)']
# ['for procurement activities with clients, it is essential to have a living room populated with buyers of medium experience for the activities we foresee in the coming weeks/months. focus on buyers relating to materials (of all disciplines)', 'for procurement activities withclients, it is essential to have a living room populated with buyers of medium experience for the activities we foresee in the coming weeks/months. focus on buyers relating to materials (of all disciplines)']
# Column: Candidate Profile, Row ID: 599, Value: 3 to 7 years' experience in the oil & gas industry, both onshore and offshore fields, with experience in process safety, hse or loss prevention in different project engineering phases -advanced knowledge of english language -advanced skills in the most common ms office applications and office365 suite -good communication, problem-solving and decision making -strong attitude to collaborate with colleagues also by means of it / digital tools|execute the process safety, hse and loss prevention activities, also at multi-disciplinary level, throughout the project. ensure discipline progress monitoring and control man-hour consumption; -execute or coordinate the main loss prevention engineering tasks (ie hazardous area classification, active and passive fire protection design, fire and gas detection system design, etc.), and manage the comments from client performed on these activities; -ensure the correct application of project procedures, engineering specifications and international codes and standards (nfpa, api, ogp, etc.); -attend to the safety reviews and assessments (hazid, hazop, sil, etc.) and manage the follow-up activity of the actions / recommendations raised during these workshops; -check and manage the risk analysis activities (qra, fera, etc.) and reliability studies (ram); -interface with client on technical issues on loss prevention design.
# ["3 to 7 years' experience in the oil & gas industry, both onshore and offshore fields, with experience in process safety, hse or loss prevention in different project engineering phases -advanced knowledge of english language -advanced skills in the most common ms office applications and office365 suite -good communication, problem-solving and decision making -strong attitude to collaborate with colleagues also by means of it / digital tools", 'execute the process safety, hse and loss prevention activities, also at multi-disciplinary level, throughout the project. ensure discipline progress monitoring and control man-hour consumption; -execute or coordinate the main loss prevention engineering tasks (ie hazardous area classification, active and passive fire protection design, fire and gas detection system design, etc.), and manage the comments from client performed on these activities; -ensure the correct application of project procedures, engineering specifications and international codes and standards (nfpa, api, ogp, etc.); -attend to the safety reviews and assessments (hazid, hazop, sil, etc.) and manage the follow-up activity of the actions / recommendations raised during these workshops; -check and manage the risk analysis activities (qra, fera, etc.) and reliability studies (ram); -interface with client on technical issues on loss prevention design.']
# ["3 to 7 years' experience in the oil & gas industry, both onshore and offshore fields, with experience in process safety, hse or loss prevention in different project engineering phases -advanced knowledge of english language -advanced skills in the most common ms office applications and office365 suite -good communication, problem-solving and decision making -strong attitude to collaborate with colleagues also by means of it / digital tools", 'execute the process safety, hse and loss prevention activities, also at multi-disciplinary level, throughout the project. ensure discipline progress monitoring and control man-hour consumption; -execute or coordinate the main loss prevention engineering tasks (ie hazardous area classification, active and passive fire protection design, fire and gas detection system design, etc.), and manage the comments from client performed on these activities; -ensure the correct application of project procedures, engineering specifications and international codes and standards (nfpa, api, ogp, etc.); -attend to the safety reviews and assessments (hazid, hazop, sil, etc.) and manage the follow-up activity of the actions / recommendations raised during these workshops; -check and manage the risk analysis activities (qra, fera, etc.) and reliability studies (ram); -interface with client on technical issues on loss prevention design.']
# Column: Job Description, Row ID: 633, Value: 2nd and 2nd level support activities onsite|3rd and 2nd level support activities onsite|4th and 2nd level support activities onsite|1st and 2nd level support activities onsite|5th and 2nd level support activities onsite
# ['2nd and 2nd level support activities onsite', '3rd and 2nd level support activities onsite', '4th and 2nd level support activities onsite', '1st and 2nd level support activities onsite', '5th and 2nd level support activities onsite']
# ['2nd and 2nd level support activities onsite', '3rd and 2nd level support activities onsite', '4th and 2nd level support activities onsite', '1st and 2nd level support activities onsite', '5th and 2nd level support activities onsite']
# Column: Job Description, Row ID: 636, Value: software engineer – microservices design & development_senior (>5 years) the activities they will have to carry out are: • requirements analysis; • software development; • sw configuration control; • unit testing; • integration tests; • system testing and validation; • sw corrective maintenance; • drafting of documentation or contributions to project documentation (manuals, architectural drawings, user stories and tests documents); • participation in technical and progress meetings.|3 software engineer – microservices design & development_senior (>5 years) the activities they will have to carry out are: • requirements analysis; • software development; • sw configuration control; • unit testing; • integration tests; • system testing and validation; • sw corrective maintenance; • drafting of documentation or contributions to project documentation (manuals, architectural drawings, user stories and tests documents); • participation in technical and progress meetings.
# ['software engineer – microservices design & development_senior (>5 years) the activities they will have to carry out are: • requirements analysis; • software development; • sw configuration control; • unit testing; • integration tests; • system testing and validation; • sw corrective maintenance; • drafting of documentation or contributions to project documentation (manuals, architectural drawings, user stories and tests documents); • participation in technical and progress meetings.', '3 software engineer – microservices design & development_senior (>5 years) the activities they will have to carry out are: • requirements analysis; • software development; • sw configuration control; • unit testing; • integration tests; • system testing and validation; • sw corrective maintenance; • drafting of documentation or contributions to project documentation (manuals, architectural drawings, user stories and tests documents); • participation in technical and progress meetings.']
# ['software engineer – microservices design & development_senior (>5 years) the activities they will have to carry out are: • requirements analysis; • software development; • sw configuration control; • unit testing; • integration tests; • system testing and validation; • sw corrective maintenance; • drafting of documentation or contributions to project documentation (manuals, architectural drawings, user stories and tests documents); • participation in technical and progress meetings.', '3 software engineer – microservices design & development_senior (>5 years) the activities they will have to carry out are: • requirements analysis; • software development; • sw configuration control; • unit testing; • integration tests; • system testing and validation; • sw corrective maintenance; • drafting of documentation or contributions to project documentation (manuals, architectural drawings, user stories and tests documents); • participation in technical and progress meetings.']
# Column: Last Role, Row ID: 844, Value: procurement specialist buyer|training member – system analyst engineer
# ['procurement specialist buyer', 'training member – system analyst engineer']
# ['procurement specialist buyer', 'training member – system analyst engineer']
# Column: Job Description, Row ID: 958, Value: support and administration of it and automation systems in gsk|support and administration of it and automation systems
# ['support and administration of it and automation systems in gsk', 'support and administration of it and automation systems']
# ['support and administration of it and automation systems in gsk', 'support and administration of it and automation systems']
# Column: Job Family Hiring, Row ID: 1094, Value: Support|Enabling Function
# ['Support', 'Enabling Function']
# ['Support', 'Enabling Function']
# Column: Last Role, Row ID: 1279, Value: analyst of logistics|metalworker tester
# ['analyst of logistics', 'metalworker tester']
# ['analyst of logistics', 'metalworker tester']
# Column: Last Role, Row ID: 1399, Value: materials & warehouse manager|logistics manager|supply chain manager
# ['materials & warehouse manager', 'logistics manager', 'supply chain manager']
# ['materials & warehouse manager', 'logistics manager', 'supply chain manager']
# Column: Candidate Profile, Row ID: 1408, Value: curricular internships|curricular internships for maserati pwt customer
# ['curricular internships', 'curricular internships for maserati pwt customer']
# ['curricular internships', 'curricular internships for maserati pwt customer']
# Column: Last Role, Row ID: 4818, Value: rspp|qhse manager|csr manager
# ['rspp', 'qhse manager', 'csr manager']
# ['rspp', 'qhse manager', 'csr manager']

# %%
final_df.columns
# Out:
# Index(['ID', 'Candidate State', 'Age Range', 'Residence', 'Sex',
#        'Protected category', 'TAG', 'Study area', 'Study Title',
#        'Years Experience', 'Sector', 'Last Role', 'Year of insertion',
#        'Recruitment Request', 'Assumption Headquarters', 'Job Family Hiring',
#        'Job Title Hiring', 'Overall', 'Job Description', 'Candidate Profile',
#        'Years Experience.1', 'Minimum Ral', 'Ral Maximum', 'Study Level',
#        'Study Area.1', 'Akkodis headquarters', 'Current Ral', 'Expected Ral',
#        'Technical Skills', 'Standing/Position', 'Comunication', 'Maturity',
#        'Dynamism', 'Mobility', 'English', 'number_of_searches', 'Hired'],
#       dtype='object')

# %% [markdown]
# ### Residence

# %%
def city_transform(city):
    if city.strip().upper() in city_mapping:
        city = city_mapping[city.strip().upper()]
    else:
        city = ' '.join([c.capitalize() if c.upper() not in ['DI','IN','DEL','A'] else c.lower() for c in city.split()])
    return city

def parse_residence(residence):
    try:
        parts = residence.split('»')
    except:
        return pd.Series([None, None, None, None, False])
    city = parts[0].strip()
    if len(parts) < 2 or '~' not in parts[1]:
        italian_residence = (city.upper() == 'ITALY')  
 
        return pd.Series([city.upper(), None, None, None, italian_residence])
    subparts = parts[1].split('~')
    province = subparts[0].strip()
    region = subparts[1].strip() if len(subparts) > 1 else None
    if province == '(COUNTRY)' or province == '(STATE)':
        country = city
    else:
        country = 'ITALY'

    country = country.capitalize()
    region = region.capitalize()
    province = province.capitalize()
    city_italian_name = city_transform(city)

    if country.upper() == 'ITALY':
        italian_residence = True
    else:
        italian_residence = False
        region = None
        province = None
        city = None
    
    return pd.Series([country, region, province, city_italian_name, city, italian_residence])

final_df[['Residence Country', 'Residence Italian Region', 'Residence Italian Province', 'Residence Italian City IT', 'Residence Italian City EN', 'Italian Residence']] = final_df['Residence'].apply(parse_residence)

european_countries = {
    'ALBANIA', 'AUSTRIA', 'BELARUS', 'BELGIUM', 'BULGARIA', 'CROATIA', 'CZECH REPUBLIC',
    'FRANCE', 'GERMANY', 'GREECE', 'LITHUANIA', 'MALTA', 'MONACO', 'NETHERLANDS',
    'PORTUGAL', 'REPUBLIC OF POLAND', 'ROMANIA', 'RUSSIAN FEDERATION', 'SAN MARINO',
    'SERBIA AND MONTENEGRO', 'SLOVAKIA', 'SPAIN', 'SWEDEN', 'SWITZERLAND', 'UKRAINE',
    'GREAT BRITAIN-NORTHERN IRELAND', 'YUGOSLAVIA', 'ITALY','TÜRKIYE', 'USSR'
}
final_df['European Residence'] = final_df['Residence Country'].apply(lambda x: x.upper() in european_countries if pd.notna(x) else False)
country_mapping = {
    "GREAT BRITAIN-NORTHERN IRELAND": "UNITED KINGDOM",
    "REPUBLIC OF POLAND":           "POLAND",
    "UNITED STATES OF AMERICA" : "UNITED STATES",
    "TÜRKIYE" : "TURKEY", "SERBIA AND MONTENEGRO": "SERBIA","YUGOSLAVIA": "SERBIA", "USSR": "RUSSIA", "CHINA PEOPLE'S REPUBLIC": "CHINA",
    "SOUTH AFRICAN REPUBLIC": "SOUTH AFRICA", "RUSSIAN FEDERATION": "RUSSIA",
}


final_df['Residence Country'] = (
    final_df['Residence Country']
      .astype(str)                   
      .str.upper()                   
      .replace(country_mapping)      
)

# %%
print(f'Assumption Headquarters Values: {final_df["Assumption Headquarters"].unique()}\nAkkodis Headquarters Values: {final_df["Akkodis headquarters"].unique()}')
# Out:
# Assumption Headquarters Values: [nan 'Bologna' 'Modena' 'Milan' 'Turin' 'Rome' 'Poggibonsi' 'Pisa' 'Udine'
#  'Toasts' 'Valenzano' 'The Eagle' 'Bari' 'Pomezia' 'Naples' 'Vicenza'
#  'Gallarate' 'Florence' 'Tramutola']
# Akkodis Headquarters Values: [nan 'Milan' 'Modena' 'Turin' 'Rome' 'Poggibonsi' 'Pisa' 'Udine'
#  'Valenzano' 'Gallarate' 'Bologna' 'Naples' 'Bari' 'Vicenza' 'Pomezia'
#  'The Eagle' 'Toasts' 'Florence' 'Genoa']

# %%
city_name_mapping = {
    "Toasts": "Brindisi",
    "The Eagle": "L'Aquila",
}
final_df['Assumption Headquarters'] = final_df['Assumption Headquarters'].replace(city_name_mapping)
final_df['Akkodis headquarters'] = final_df['Akkodis headquarters'].replace(city_name_mapping)
print(f'Assumption Headquarters Values: {final_df["Assumption Headquarters"].unique()}\nAkkodis Headquarters Values: {final_df["Akkodis headquarters"].unique()}')
# Out:
# Assumption Headquarters Values: [nan 'Bologna' 'Modena' 'Milan' 'Turin' 'Rome' 'Poggibonsi' 'Pisa' 'Udine'
#  'Brindisi' 'Valenzano' "L'Aquila" 'Bari' 'Pomezia' 'Naples' 'Vicenza'
#  'Gallarate' 'Florence' 'Tramutola']
# Akkodis Headquarters Values: [nan 'Milan' 'Modena' 'Turin' 'Rome' 'Poggibonsi' 'Pisa' 'Udine'
#  'Valenzano' 'Gallarate' 'Bologna' 'Naples' 'Bari' 'Vicenza' 'Pomezia'
#  "L'Aquila" 'Brindisi' 'Florence' 'Genoa']

# %%
import os
import time
import json
import requests
import pandas as pd

country_coords = {}
country_file_path = '../countries.csv'

if os.path.exists(country_file_path):
    try:
        countries_df = pd.read_csv(country_file_path)
        country_coords = {
            row['name'].upper(): {
                'latitude': row['latitude'],
                'longitude': row['longitude']
            }
            for _, row in countries_df.iterrows()
        }
        print(f"Successfully loaded country data from '{country_file_path}'.")
    except FileNotFoundError:
        print(f"Error: '{country_file_path}' not found.")
    except pd.errors.EmptyDataError:
        print(f"Error: '{country_file_path}' is empty.")
    except pd.errors.ParserError:
        print(f"Error: Could not parse '{country_file_path}'. Check CSV format.")
    except Exception as e:
        print(f"An unexpected error occurred while reading '{country_file_path}': {e}")
else:
    print(f"Warning: '{country_file_path}' not found. Country lookups will not be possible.")

cities_file = '../simplemaps_worldcities_basicv1.90/worldcities.csv'
if os.path.exists(cities_file):
    cities = pd.read_csv(cities_file)
    print(f"Loaded cities data from '{cities_file}', {len(cities)} rows.")
else:
    raise FileNotFoundError(f"Cities file not found at '{cities_file}'")
# Out:
# Successfully loaded country data from '../countries.csv'.
# Loaded cities data from '../simplemaps_worldcities_basicv1.90/worldcities.csv', 48056 rows.

# %%
def get_headquarter_coordinates(city_name):
    """
    Returns (latitude, longitude) for a headquarters city in Italy.
    Looks up in the local 'cities' DataFrame only.
    """

    if pd.isna(city_name) or not city_name:
        return None, None

    mask = (
        (cities['city_ascii'].str.upper() == str(city_name).upper()) &
        (cities['iso2'] == 'IT')
    )
    if mask.any():
        row = cities.loc[mask].iloc[0]
        return row['lat'], row['lng']
    else:
        print(f"Headquarters city '{city_name}' not found in Italy.")
        return None, None
final_df[['Assumption HQ Lat', 'Assumption HQ Lng']] = final_df['Assumption Headquarters'].apply(
    lambda x: pd.Series(get_headquarter_coordinates(x))
)

final_df[['Akkodis HQ Lat', 'Akkodis HQ Lng']] = final_df['Akkodis headquarters'].apply(
    lambda x: pd.Series(get_headquarter_coordinates(x))
)
# Out:
# Headquarters city 'Tramutola' not found in Italy.

# %%
def get_city_coordinates(city_en, city_it):
    """
    Returns (latitude, longitude) for an Italian city by looking it up in the 'cities' DataFrame.
    If not found or not an Italian city, falls back to the Back4App API.
    """
    if pd.isna(city_en) or not city_en:
        return None, None

    mask = (
        (cities['city_ascii'].str.upper() == str(city_en).replace("'","").strip().upper()) &
        (cities['iso2'] == 'IT')
    )
    if mask.any():
        row = cities.loc[mask].iloc[0]
        return row['lat'], row['lng']
    mask = (
        (cities['city_ascii'].str.upper() == str(city_it).replace("'","").strip().upper()) &
        (cities['iso2'] == 'IT')
    )
    if mask.any():
        row = cities.loc[mask].iloc[0]
        return row['lat'], row['lng']
    
    city_name_str = str(city_it)
    try:
        where = urllib.parse.quote_plus(json.dumps({"name": city_name_str}))
        url = (
            'https://parseapi.back4app.com/classes/City'
            f'?limit=1&keys=name,location&where={where}'
        )
        headers = {
            'X-Parse-Application-Id': 'rPfDpoNwAXlUjYrLAYtkVa6HXYcorAOJ9pefs00V',
            'X-Parse-Master-Key': 'rpXD45YgCcmIyLf13fwUsguY9hRPaiH4xaIPsQLT'
        }
        resp = requests.get(url, headers=headers, timeout=10)
        resp.raise_for_status()
        results = resp.json().get('results', [])
        if results:
            loc = results[0].get('location', {})
            return loc.get('latitude'), loc.get('longitude')
    except requests.RequestException:
        pass
    city_name_str = str(city_en)
    try:
        where = urllib.parse.quote_plus(json.dumps({"name": city_name_str}))
        url = (
            'https://parseapi.back4app.com/classes/City'
            f'?limit=1&keys=name,location&where={where}'
        )
        headers = {
            'X-Parse-Application-Id': 'rPfDpoNwAXlUjYrLAYtkVa6HXYcorAOJ9pefs00V',
            'X-Parse-Master-Key': 'rpXD45YgCcmIyLf13fwUsguY9hRPaiH4xaIPsQLT'
        }
        resp = requests.get(url, headers=headers, timeout=10)
        resp.raise_for_status()
        results = resp.json().get('results', [])
        if results:
            loc = results[0].get('location', {})
            return loc.get('latitude'), loc.get('longitude')
    except requests.RequestException:
        pass
    print(f"City '{city_it}' not found in API response.")
    print(f"City '{city_en}' not found in API response.")
    return None, None

def get_location_coordinates(row):
    """
    For each row, attempts:
      1) Italian city lookup via `cities` DataFrame
      2) Country lookup via `countries.csv`
      3) API fallback (already inside get_city_coordinates)
    Returns a Series [latitude, longitude].
    """
    city_it = row.get('Residence Italian City IT')
    city_en = row.get('Residence Italian City EN')
    country = row.get('Residence Country')
    lat, lng = None, None
    if city_en and city_en.lower() != 'italy':
        lat, lng = get_city_coordinates(city_en, city_it)
    
    if lat is None or lng is None:
        cu = str(country).upper() if pd.notna(country) else None
        if cu and cu in country_coords:
            lat = country_coords[cu]['latitude']
            lng = country_coords[cu]['longitude']
        else:
            info = []
            if pd.notna(city_it):   info.append(f"city '{city_it}'")
            if pd.notna(country): info.append(f"country '{cu}'")
            print(f"Coordinates not found for {' and '.join(info)}.")

    return pd.Series({'Latitude': lat, 'Longitude': lng})


from tqdm import tqdm

tqdm.pandas(desc="Geocoding rows") 

final_df[['Residence Lat', 'Residence Lon']] = final_df.progress_apply(get_location_coordinates, axis=1)
# Out:
# Geocoding rows:  15%|█▍        | 712/4870 [00:52<06:02, 11.46it/s]
# Coordinates not found for country 'NONE'.
# Geocoding rows: 100%|██████████| 4870/4870 [04:57<00:00, 16.35it/s]

# %% [markdown]
# ### Save Preprocessed Dataframe

# %%
final_df.to_csv('preprocessed_df.csv', index=False)

# %% [markdown]
# ## Create final dataset

# %% [markdown]
# ### Load Preprocessed Dataframe

# %%
import pandas as pd

final_df = pd.read_csv('preprocessed_df.csv')

# %%
final_df.columns
# Out:
# Index(['ID', 'Candidate State', 'Age Range', 'Residence', 'Sex',
#        'Protected category', 'TAG', 'Study area', 'Study Title',
#        'Years Experience', 'Sector', 'Last Role', 'Year of insertion',
#        'Recruitment Request', 'Assumption Headquarters', 'Job Family Hiring',
#        'Job Title Hiring', 'Overall', 'Job Description', 'Candidate Profile',
#        'Years Experience.1', 'Minimum Ral', 'Ral Maximum', 'Study Level',
#        'Study Area.1', 'Akkodis headquarters', 'Current Ral', 'Expected Ral',
#        'Technical Skills', 'Standing/Position', 'Comunication', 'Maturity',
#        'Dynamism', 'Mobility', 'English', 'number_of_searches', 'Hired',
#        'Residence Country', 'Residence Italian Region',
#        'Residence Italian Province', 'Residence Italian City IT',
#        'Residence Italian City EN', 'Italian Residence', 'European Residence',
#        'Assumption HQ Lat', 'Assumption HQ Lng', 'Akkodis HQ Lat',
#        'Akkodis HQ Lng', 'Residence Lat', 'Residence Lon', 'candidate_text',
#        'Distance Residence - Akkodis HQ',
#        'Distance Residence - Assumption HQ'],
#       dtype='object')

# %% [markdown]
# ### Final Features

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
from tqdm import tqdm
import random

candidate_columns = [
    "Sex",
    "Age Range",
    "Protected category",
    "Italian Residence",
    "European Residence",
    "Protected category",
    "TAG",
    "Study area",
    "Study Title",
    "Years Experience",
    "Sector",
    "Last Role",
    "Current Ral",
    "Expected Ral",
    "Residence Lat",
    "Residence Lon",
    "Overall",
    "Technical Skills",
    "Standing/Position",
    "Comunication",
    "Maturity",
    "Dynamism",
    "Mobility",
    "English",
]
job_columns = [
    "Recruitment Request",
    "Job Family Hiring",
    "Job Title Hiring",
    "Job Description",
    "Candidate Profile",
    "Years Experience.1",
    "Minimum Ral",
    "Ral Maximum",
    "Study Level",
    "Study Area.1",
    "Akkodis HQ Lat",
    "Akkodis HQ Lng",
    "Assumption HQ Lat",
    "Assumption HQ Lng",
    "number_of_searches",
]

candidates = final_df[candidate_columns + ["Year of insertion", "Hired"]].copy()
jobs = final_df[job_columns + ["Year of insertion"]].copy()

valid_candidates = candidates[candidates[candidate_columns].notna().any(axis=1)].copy()
valid_jobs = jobs[jobs[job_columns].notna().any(axis=1)].drop_duplicates().copy()

final_df["candidate_text"] = final_df.apply(create_candidate_text, axis=1)
valid_jobs["job_text"] = valid_jobs.apply(create_job_text, axis=1)

model = SentenceTransformer("all-MiniLM-L6-v2")
valid_jobs = valid_jobs.reset_index()

candidate_embeddings = model.encode(
    final_df["candidate_text"].fillna("").tolist(), show_progress_bar=True
)
job_embeddings = model.encode(
    valid_jobs["job_text"].fillna("").tolist(), show_progress_bar=True
)

cos_sim_matrix = cosine_similarity(candidate_embeddings, job_embeddings)
# Out:
# Batches:   0%|          | 0/153 [00:00<?, ?it/s]
# Batches:   0%|          | 0/48 [00:00<?, ?it/s]

# %%
new_dataset = []

for idx, row in tqdm(final_df.iterrows(), total=len(final_df)):
    year = row['Year of insertion']
    hired = row['Hired']
    cand_text = row['candidate_text']
    full_candidate_data = row[candidate_columns].to_dict()

    same_year_mask = valid_jobs['Year of insertion'] == year
    year_job_indices = valid_jobs[same_year_mask].index.tolist()
   
    if not year_job_indices:
        print('No year')
        continue

    similarities = [cos_sim_matrix[idx][j] for j in year_job_indices]


    if hired == 1:
        job_data = row[job_columns].to_dict()
        new_dataset.append({**full_candidate_data, **job_data, "Hired": 1})
        low_sim_indices = sorted(zip(year_job_indices, similarities), key=lambda x: x[1])[:3]
        low_sample_idx = random.choice(low_sim_indices)[0]
        job_data_neg = valid_jobs.loc[low_sample_idx][job_columns].to_dict()
        new_dataset.append({**full_candidate_data, **job_data_neg, "Hired": 0})

    elif hired == 0:
        low_sim_indices = sorted(zip(year_job_indices, similarities), key=lambda x: x[1])[:3]
        high_sim_indices = sorted(zip(year_job_indices, similarities), key=lambda x: x[1], reverse=True)[:8]
        low_sample_idx = random.choice(low_sim_indices)[0]
        high_sample_idx = random.choice(high_sim_indices)[0]
        
        job_data_low = valid_jobs.loc[low_sample_idx][job_columns].to_dict()
        job_data_high = valid_jobs.loc[high_sample_idx][job_columns].to_dict()
        new_dataset.append({**full_candidate_data, **job_data_low, "Hired": 0})
        new_dataset.append({**full_candidate_data, **job_data_high, "Hired": 0})


dataset = pd.DataFrame(new_dataset)
dataset.head()
# Out:
# 100%|██████████| 4870/4870 [00:09<00:00, 505.92it/s]
#       Sex      Age Range  Protected category Italian Residence  \
# 0  Female  26 - 30 years               False              True
# 1  Female  26 - 30 years               False              True
# 2  Female     < 20 years               False              True
# 3  Female     < 20 years               False              True
# 4    Male  26 - 30 years               False              True
#
#    European Residence                                                TAG  \
# 0                True  -, 3D PRINTING PREFORM SOFTWARE; PYTHON; ANSYS...
# 1                True  -, 3D PRINTING PREFORM SOFTWARE; PYTHON; ANSYS...
# 2                True                                 PROJECT MANAGEMENT
# 3                True                                 PROJECT MANAGEMENT
# 4                True                               ANGULAR, JAVASCRIPT.
#
#                Study area        Study Title Years Experience   Sector  ...  \
# 0  Biomedical Engineering   Five-year degree              [0]      NaN  ...
# 1  Biomedical Engineering   Five-year degree              [0]      NaN  ...
# 2  Management Engineering   Five-year degree              [0]   Others  ...
# 3  Management Engineering   Five-year degree              [0]   Others  ...
# 4             Informatics  Three-year degree            [1-3]  Telecom  ...
#
#   Minimum Ral  Ral Maximum        Study Level            Study Area.1  \
# 0         NaN          NaN                NaN                     NaN
# 1     25000.0      29000.0   Five-year degree  Mechanical engineering
# 2         NaN          NaN                NaN                     NaN
# 3         NaN          NaN   Five-year degree  Mechanical engineering
# 4     23000.0      29000.0  Three-year degree             Informatics
#
#    Akkodis HQ Lat  Akkodis HQ Lng  Assumption HQ Lat  Assumption HQ Lng  \
# 0             NaN             NaN                NaN                NaN
# 1         45.4669            9.19            45.4669             9.1900
# 2             NaN             NaN                NaN                NaN
# 3         45.4669            9.19            45.4669             9.1900
# 4         45.4669            9.19            44.4939            11.3428
#
#    number_of_searches  Hired
# 0           93.000000      0
# 1          651.666667      0
# 2          895.000000      0
# 3          899.000000      0
# 4          337.000000      1
#
# [5 rows x 39 columns]

# %%
cat_order = {
    'Age Range': ['< 20 years', '20 - 25 years', '26 - 30 years', '31 - 35 years', '36 - 40 years', '40 - 45 years', '> 45 years'],
    'Years Experience': ['[0]', '[0-1]', '[1-3]', '[3-5]', '[5-7]', '[7-10]', '[+10]'],
    'Years Experience.1': ['[0]', '[0-1]',  '[1-3]', '[3-5]', '[5-7]', '[7-10]','[+10]'],
    'Sex': ['Female','Male'],
    'Study Level':[
        "Middle school diploma",
        "High school graduation",
        "Professional qualification",
        "Three-year degree",
        "Five-year degree",
        "master's degree",
        "Doctorate"
    ], 
    'Study Title':[
        "Middle school diploma",
        "High school graduation",
        "Professional qualification",
        "Three-year degree",
        "Five-year degree",
        "master's degree",
        "Doctorate"
    ]
}

for col, order in cat_order.items():
    if col in dataset.columns:
        dataset[col+'_int'] = pd.Categorical(dataset[col], categories=order, ordered=True)
        dataset[col+'_int'] = dataset[col+'_int'].cat.codes.replace(-1, pd.NA)
dataset['Study Level_int'] = (
dataset['Study Level_int']
.astype('Int64') 
)
dataset['Years Experience.1_int'] = dataset['Years Experience.1_int'].fillna(4)
dataset['experience_match_score'] = calculate_experience_match_score(dataset)

dataset['current_salary_fit_score'] = calculate_salary_fit_score(dataset, is_expected=False)
dataset['expected_salary_fit_score'] = calculate_salary_fit_score(dataset, is_expected=True)
dataset['study_title_score'] = calculate_study_title_score(dataset)
dataset['professional_similarity_score'] = calculate_professional_similarity_score(dataset)
dataset['study_area_score'] = calculate_study_area_score(dataset)

dataset['Distance Residence - Akkodis HQ'] = dataset.apply(
    lambda row: calculate_distance(
        (row['Residence Lat'], row['Residence Lon']),
        (row['Akkodis HQ Lat'], row['Akkodis HQ Lng'])
    ),
    axis=1
)

dataset['Distance Residence - Assumption HQ'] = dataset.apply(
    lambda row: calculate_distance(
        (row['Residence Lat'], row['Residence Lon']),
        (row['Assumption HQ Lat'], row['Assumption HQ Lng'])
    ),
    axis=1
)

# %%
dataset = prepare_nlp_text_columns(dataset)

# %%
from sentence_transformers import SentenceTransformer, util
import numpy as np

model = SentenceTransformer('all-MiniLM-L6-v2')

def compute_general_similarity_score(df: pd.DataFrame) -> pd.Series:
    embedding_cache = {}

    def get_embedding(text):
        if text in embedding_cache:
            return embedding_cache[text]
        embedding = model.encode(text, convert_to_tensor=True)
        embedding_cache[text] = embedding
        return embedding

    def similarity(row):
        candidate_text = row.get('candidate_text')
        job_text = row.get('job_text')

        if not candidate_text or not job_text:
            return np.nan

        emb_a = get_embedding(candidate_text)
        emb_b = get_embedding(job_text)
        return float(util.cos_sim(emb_a, emb_b))

    return df.apply(similarity, axis=1)
dataset['general_similarity_score'] = compute_general_similarity_score(dataset)

# %%
from sentence_transformers import CrossEncoder
import pandas as pd
import numpy as np
from tqdm.auto import tqdm
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"

cross_model = CrossEncoder("cross-encoder/ms-marco-MiniLM-L6-v2", device=device)
def compute_similarity_with_prompt(df: pd.DataFrame, batch_size: int = 256) -> pd.Series:
    valid_df = df[['candidate_text', 'job_text']].dropna()
    pairs = valid_df.values.tolist()
    
    tokenizer = cross_model.tokenizer
    prompted_pairs = []

    for cand, job in pairs:
        prompted_pairs.append((
            job,
            cand
        ))

 
    scores = cross_model.predict(prompted_pairs, batch_size=batch_size, show_progress_bar=True)
    
    result = pd.Series(np.nan, index=df.index, dtype=np.float32)
    result.loc[valid_df.index] = scores
    return result

dataset['general_similarity_score_cross'] = compute_similarity_with_prompt(dataset)
# Out:
# Batches:   0%|          | 0/39 [00:00<?, ?it/s]

# %%
tfidf = TfidfVectorizer(
    max_features=5000,   
    stop_words='english'
)

combined_text = pd.concat([dataset['candidate_text'], dataset['job_text']])
tfidf.fit(combined_text.fillna(""))

candidate_tfidf = tfidf.transform(dataset['candidate_text'].fillna(""))
job_tfidf = tfidf.transform(dataset['job_text'].fillna(""))
from sklearn.metrics.pairwise import cosine_similarity

candidate_tfidf_dense = candidate_tfidf.toarray()
job_tfidf_dense = job_tfidf.toarray()

tfidf_sim_matrix = cosine_similarity(candidate_tfidf_dense, job_tfidf_dense)

dataset['general_similarity_score_tfidf'] = tfidf_sim_matrix.max(axis=1)

# %%
columns_to_keep = [
    "Sex_int",
    "Protected category",
    "Overall",
    "Technical Skills",
    "Standing/Position",
    "Comunication",
    "Maturity",
    "Dynamism",
    "Mobility",
    "English",
    "Hired",
    "Italian Residence",
    "European Residence",
    "Age Range_int",
    "experience_match_score",
    "Years Experience_int",
    "Years Experience.1_int",
    "current_salary_fit_score",
    "Current Ral",
    "Expected Ral",
    "Minimum Ral",
    "Ral Maximum",
    "expected_salary_fit_score",
    "study_title_score",
    "Study Level_int",
    "Study Title_int",
    "professional_similarity_score",
    "study_area_score",
    "general_similarity_score",
    "general_similarity_score_tfidf",
    "general_similarity_score_cross",
    "number_of_searches",
    "Distance Residence - Akkodis HQ",
    "Distance Residence - Assumption HQ",
]

# %% [markdown]
# ### Dataset Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df_corr = dataset[columns_to_keep].copy()

bool_cols = df_corr.select_dtypes(include='bool').columns
df_corr[bool_cols] = df_corr[bool_cols].astype(int)

df_corr_numeric = df_corr.select_dtypes(include=[np.number])

plt.figure(figsize=(20, 10))
sns.heatmap(df_corr_numeric.corr(), annot=False, 
              cmap="coolwarm", center=0, square=True)
plt.title("Full Correlation Matrix")
plt.tight_layout()
plt.show()

correlations = df_corr_numeric.corr()['Hired'].drop('Hired').sort_values()

plt.figure(figsize=(10, 6))
sns.stripplot(y=correlations.values, x=correlations.index, color='darkgreen', size=10)
plt.axhline(0, color='gray', linestyle='--')
plt.title("Feature Correlations with 'Hired'")
plt.ylabel("Correlation Coefficient")
plt.xlabel("Features")
plt.xticks(rotation=45, ha='right')
plt.grid(True, axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
print("Hiring Rate by Sex:")
distribution_by_sex = dataset.groupby('Sex')['Hired'].mean()
print(distribution_by_sex)

print("Hiring Rate by European Residence:")
distribution_by_eu_residence = dataset.groupby('European Residence')['Hired'].mean()
print(distribution_by_eu_residence)

print("Hiring Rate by Italian Residence:")
distribution_by_it_residence = dataset.groupby('Italian Residence')['Hired'].mean()
print(distribution_by_it_residence)

print("\nHiring Rate by Age Range:")
distribution_by_age = dataset.groupby('Age Range')['Hired'].mean()
print(distribution_by_age)

print("\nHiring Rate by Protected Category:")
distribution_by_category = dataset.groupby('Protected category')['Hired'].mean()
print(distribution_by_category)

sns.barplot(x='Sex', y='Hired', data=dataset, estimator=np.mean, palette='Set2')
plt.title("Hiring Rate by Sex")
plt.ylim(0, 1.2 * max(distribution_by_sex))
plt.ylabel("Proportion Hired")
plt.show()

sns.barplot(x='European Residence', y='Hired', data=dataset, estimator=np.mean, palette='Set2')
plt.title("Hiring Rate by European Residence")
plt.ylim(0, 1.2 * max(distribution_by_eu_residence))
plt.ylabel("Proportion Hired")
plt.show()

sns.barplot(x='Italian Residence', y='Hired', data=dataset, estimator=np.mean, palette='Set2')
plt.title("Hiring Rate by Italian Residence")
plt.ylim(0, 1.2 * max(distribution_by_it_residence))
plt.ylabel("Proportion Hired")
plt.show()

sns.barplot(x='Age Range', y='Hired', data=dataset, estimator=np.mean, palette='Set3')
plt.title("Hiring Rate by Age Range")
plt.ylim(0, 1.3 * max(distribution_by_age))
plt.xticks(rotation=45)
plt.ylabel("Proportion Hired")
plt.show()

sns.barplot(x='Protected category', y='Hired', data=dataset, estimator=np.mean, palette='Set1')
plt.title("Hiring Rate by Protected Category")
plt.ylim(0, 1.2 * max(distribution_by_category))
plt.ylabel("Proportion Hired")
plt.show()
# Out:
# Hiring Rate by Sex:
# Sex
# Female    0.073779
# Male      0.047324
# Name: Hired, dtype: float64
# Hiring Rate by European Residence:
# European Residence
# False    0.011364
# True     0.053534
# Name: Hired, dtype: float64
# Hiring Rate by Italian Residence:
# Italian Residence
# False    0.018293
# True     0.054677
# Name: Hired, dtype: float64
#
# Hiring Rate by Age Range:
# Age Range
# 20 - 25 years    0.033821
# 26 - 30 years    0.050131
# 31 - 35 years    0.077047
# 36 - 40 years    0.081040
# 40 - 45 years    0.078199
# < 20 years       0.030227
# > 45 years       0.060475
# Name: Hired, dtype: float64
#
# Hiring Rate by Protected Category:
# Protected category
# False    0.052784
# True     0.051282
# Name: Hired, dtype: float64

# %%
summary_sex = dataset.groupby('Sex')['Hired'].agg(['mean', 'count']).rename(columns={'mean': 'Hiring Rate', 'count': 'Number of Candidates'})
print("\nHiring Rate and Count by Sex:\n", summary_sex)

summary_eu_residence = dataset.groupby('European Residence')['Hired'].agg(['mean', 'count']).rename(columns={'mean': 'Hiring Rate', 'count': 'Number of Candidates'})
print("\nHiring Rate and Count by European Residence:\n", summary_eu_residence)

summary_it_residence = dataset.groupby('Italian Residence')['Hired'].agg(['mean', 'count']).rename(columns={'mean': 'Hiring Rate', 'count': 'Number of Candidates'})
print("\nHiring Rate and Count by Italian Residence:\n", summary_it_residence)

summary_age = dataset.groupby('Age Range')['Hired'].agg(['mean', 'count']).rename(columns={'mean': 'Hiring Rate', 'count': 'Number of Candidates'}).sort_index()
print("\nHiring Rate and Count by Age Range:\n", summary_age)

summary_protected = dataset.groupby('Protected category')['Hired'].agg(['mean', 'count']).rename(columns={'mean': 'Hiring Rate', 'count': 'Number of Candidates'})
print("\nHiring Rate and Count by Protected Category:\n", summary_protected)
# Out:
# Hiring Rate and Count by Sex:
#          Hiring Rate  Number of Candidates
# Sex
# Female     0.073779                  2006
# Male       0.047324                  7734
#
# Hiring Rate and Count by European Residence:
#                      Hiring Rate  Number of Candidates
# European Residence
# False                  0.011364                   176
# True                   0.053534                  9564
#
# Hiring Rate and Count by Italian Residence:
#                     Hiring Rate  Number of Candidates
# Italian Residence
# False                 0.018293                   492
# True                  0.054677                  9236
#
# Hiring Rate and Count by Age Range:
#                 Hiring Rate  Number of Candidates
# Age Range
# 20 - 25 years     0.033821                  1094
# 26 - 30 years     0.050131                  3810
# 31 - 35 years     0.077047                  1246
# 36 - 40 years     0.081040                   654
# 40 - 45 years     0.078199                   422
# < 20 years        0.030227                  1588
# > 45 years        0.060475                   926
#
# Hiring Rate and Count by Protected Category:
#                      Hiring Rate  Number of Candidates
# Protected category
# False                  0.052784                  9662
# True                   0.051282                    78

# %%
intersection = dataset.groupby(['Sex', 'Age Range'])['Hired'].mean().unstack()
print("\nHiring Rate by Sex and Age Range:")
print(intersection)

sns.heatmap(intersection, annot=True, cmap='Blues', fmt=".2f")
plt.title("Hiring Rates by Sex and Age Range")
plt.ylabel("Sex")
plt.xlabel("Age Range")
plt.show()
# Out:
# Hiring Rate by Sex and Age Range:
# Age Range  20 - 25 years  26 - 30 years  31 - 35 years  36 - 40 years  \
# Sex
# Female          0.030612       0.068235       0.133588       0.101449
# Male            0.035000       0.044932       0.061992       0.075581
#
# Age Range  40 - 45 years  < 20 years  > 45 years
# Sex
# Female          0.134615    0.038690    0.162162
# Male            0.070270    0.027955    0.051643

# %%
p_selected_female = dataset[dataset['Sex'] == 'Female']['Hired'].mean()
p_selected_male = dataset[dataset['Sex'] == 'Male']['Hired'].mean()

disparate_impact = p_selected_female / p_selected_male
print("\nDisparate Impact Ratio (Female vs Male):", round(disparate_impact, 3))
# Out:
# Disparate Impact Ratio (Female vs Male): 1.559

# %% [markdown]
# **Analysis of Hiring Rates**
#
# **1. Gender (Sex)**
# Females are hired at a significantly higher rate than males, suggesting a possible organizational emphasis on gender diversity or a potential bias favoring female candidates.
#
# **2. Age Range**
# Hiring rates increase with age, peaking between 31–45 years, indicating a clear preference for mid-career professionals with more experience. Younger candidates, especially under 26, face notably lower hiring chances.
#
# **3. European Residence**
# Candidates residing in Europe are far more likely to be hired, which may reflect logistical preferences, legal work eligibility, or alignment with company locations and operations.
#
# **4. Italian Residence**
# There is a strong hiring bias toward candidates living in Italy. This suggests the organization prefers local hires, potentially to reduce relocation costs or due to legal/employment constraints.
#
# **5. Protected Category**
# No meaningful difference in hiring rates between protected and non-protected groups was found. However, due to the very small sample of protected category candidates, no reliable conclusion can be drawn.

# %% [markdown]
# ### Drop Nan Values

# %%
import pandas as pd

df = dataset.copy()

print(f"{'Column':30} | {'Rows Before':10} | {'Rows After':10} | {'Hired Before':12} | {'Hired After':11} | {'% Hired Before':14} | {'% Hired After':13}")
print("-" * 105)

rows_before = len(df)
hired_before = df['Hired'].sum()
perc_hired_before = hired_before / rows_before * 100

for col in columns_to_keep:
    df_dropped = df.dropna(subset=[col])
    
    rows_after = len(df_dropped)
    hired_after = df_dropped['Hired'].sum()
    
    perc_hired_after = hired_after / rows_after * 100 if rows_after > 0 else 0
    
    print(f"{col:30} | {rows_before:<10} | {rows_after:<10} | {hired_before:<12} | {hired_after:<11} | {perc_hired_before:<14.2f} | {perc_hired_after:<13.2f}")
# Out:
# Column                         | Rows Before | Rows After | Hired Before | Hired After | % Hired Before | % Hired After
# ---------------------------------------------------------------------------------------------------------
# Sex_int                        | 9740       | 9740       | 514          | 514         | 5.28           | 5.28
# Protected category             | 9740       | 9740       | 514          | 514         | 5.28           | 5.28
# Overall                        | 9740       | 4410       | 514          | 509         | 5.28           | 11.54
# Technical Skills               | 9740       | 4398       | 514          | 509         | 5.28           | 11.57
# Standing/Position              | 9740       | 4398       | 514          | 509         | 5.28           | 11.57
# Comunication                   | 9740       | 4398       | 514          | 509         | 5.28           | 11.57
# Maturity                       | 9740       | 4398       | 514          | 509         | 5.28           | 11.57
# Dynamism                       | 9740       | 4396       | 514          | 509         | 5.28           | 11.58
# Mobility                       | 9740       | 4396       | 514          | 509         | 5.28           | 11.58
# English                        | 9740       | 4390       | 514          | 509         | 5.28           | 11.59
# Hired                          | 9740       | 9740       | 514          | 514         | 5.28           | 5.28
# Italian Residence              | 9740       | 9728       | 514          | 514         | 5.28           | 5.28
# European Residence             | 9740       | 9740       | 514          | 514         | 5.28           | 5.28
# Age Range_int                  | 9740       | 9740       | 514          | 514         | 5.28           | 5.28
# experience_match_score         | 9740       | 9740       | 514          | 514         | 5.28           | 5.28
# Years Experience_int           | 9740       | 9740       | 514          | 514         | 5.28           | 5.28
# Years Experience.1_int         | 9740       | 9740       | 514          | 514         | 5.28           | 5.28
# current_salary_fit_score       | 9740       | 246        | 514          | 68          | 5.28           | 27.64
# Current Ral                    | 9740       | 1280       | 514          | 133         | 5.28           | 10.39
# Expected Ral                   | 9740       | 1144       | 514          | 149         | 5.28           | 13.02
# Minimum Ral                    | 9740       | 1628       | 514          | 237         | 5.28           | 14.56
# Ral Maximum                    | 9740       | 2453       | 514          | 310         | 5.28           | 12.64
# expected_salary_fit_score      | 9740       | 228        | 514          | 82          | 5.28           | 35.96
# study_title_score              | 9740       | 4730       | 514          | 438         | 5.28           | 9.26
# Study Level_int                | 9740       | 4730       | 514          | 438         | 5.28           | 9.26
# Study Title_int                | 9740       | 9740       | 514          | 514         | 5.28           | 5.28
# professional_similarity_score  | 9740       | 4426       | 514          | 471         | 5.28           | 10.64
# study_area_score               | 9740       | 4730       | 514          | 438         | 5.28           | 9.26
# general_similarity_score       | 9740       | 9740       | 514          | 514         | 5.28           | 5.28
# general_similarity_score_tfidf | 9740       | 9740       | 514          | 514         | 5.28           | 5.28
# general_similarity_score_cross | 9740       | 9740       | 514          | 514         | 5.28           | 5.28
# number_of_searches             | 9740       | 9735       | 514          | 509         | 5.28           | 5.23
# Distance Residence - Akkodis HQ | 9740       | 4729       | 514          | 438         | 5.28           | 9.26
# Distance Residence - Assumption HQ | 9740       | 4895       | 514          | 510         | 5.28           | 10.42

# %%
df_cleaned = dataset.dropna(subset=[ 'professional_similarity_score', ])

print(f"Original data shape: {dataset.shape,(dataset['Hired']==True).sum()}")
print(f"Cleaned data shape: {df_cleaned.shape,(df_cleaned['Hired']==True).sum()}")
# Out:
# Original data shape: ((9740, 58), np.int64(514))
# Cleaned data shape: ((4426, 58), np.int64(471))

# %% [markdown]
# ## Training

# %% [markdown]
# ### Models Comparison

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score
from sklearn.ensemble import RandomForestClassifier, HistGradientBoostingClassifier, VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

from imblearn.over_sampling import SMOTE, ADASYN
from imblearn.under_sampling import RandomUnderSampler
from imblearn.ensemble import BalancedRandomForestClassifier

df = df_cleaned[columns_to_keep].copy()
X = df.drop(columns=['Hired'])
y = df['Hired']

bool_cols = X.select_dtypes(include='bool').columns
non_bool_cols = [c for c in X.columns.difference(bool_cols) if c != 'Sex_int']
X[bool_cols] = X[bool_cols].astype(int)

scaler = StandardScaler()
X[non_bool_cols] = scaler.fit_transform(X[non_bool_cols])

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

imputer = SimpleImputer(strategy='mean')
X_train_imputed = pd.DataFrame(imputer.fit_transform(X_train), columns=X_train.columns)
X_test_imputed = pd.DataFrame(imputer.transform(X_test), columns=X_test.columns)

undersampler_orig = RandomUnderSampler(sampling_strategy='majority', random_state=42)
X_train_under_orig, y_train_under_orig = undersampler_orig.fit_resample(X_train, y_train)

X_train_upsampled, y_train_upsampled = ADASYN().fit_resample(X_train_imputed, y_train)
downsampler_impl = RandomUnderSampler(sampling_strategy='majority', random_state=42)
X_train_downsampled, y_train_downsampled = downsampler_impl.fit_resample(X_train_imputed, y_train)

models = {
    'RandomForest': lambda: RandomForestClassifier(class_weight='balanced', random_state=42, max_depth=10, min_samples_split=5, n_estimators=100),
    'HistGradientBoosting': lambda: HistGradientBoostingClassifier(random_state=42),
    'XGBoost': lambda: XGBClassifier(scale_pos_weight=(y_train == 0).sum() / (y_train == 1).sum(), random_state=42, eval_metric='logloss', max_depth=6),
    'LightGBM': lambda: LGBMClassifier(class_weight='balanced', random_state=42, max_depth=6, min_data_in_leaf=20, verbosity=-1),
    'LogisticRegression': lambda: LogisticRegression(class_weight='balanced', max_iter=1000, penalty='l2', C=0.1, solver='liblinear', random_state=42),
    'CatBoost': lambda: CatBoostClassifier(auto_class_weights='Balanced', silent=True, random_state=42, l2_leaf_reg=3, iterations=500, depth=6, learning_rate=0.05),
    'BalancedRF': lambda: BalancedRandomForestClassifier(random_state=42)
}

ensemble = lambda: VotingClassifier(
    estimators=[
        ('xgb', models['XGBoost']()),
        ('lgbm', models['LightGBM']()),
        ('cat', models['CatBoost']()),
        ('hist', models['HistGradientBoosting']()),
        ('brf', models['BalancedRF']())
    ],
    voting='soft'
)
models['Ensemble'] = ensemble

results_train = {}
results_test = {}

for strategy_name in ['Downsample', 'Original', 'Upsample']:
    strategy_results_train = []
    strategy_results_test = []
    
    for model_name, model in models.items():
        model = model()
        if strategy_name == 'Original':
            if model_name in ['XGBoost', 'LightGBM', 'CatBoost']:
                X_tr = X_train
                y_tr = y_train
                X_te = X_test
            else:
                X_tr = X_train_imputed
                y_tr = y_train
                X_te = X_test_imputed
        elif strategy_name == 'Upsample':
            X_tr = X_train_upsampled
            y_tr = y_train_upsampled
            X_te = X_test_imputed
        elif strategy_name == 'Downsample':
            X_tr = X_train_downsampled
            y_tr = y_train_downsampled
            X_te = X_test_imputed  
    
        model.fit(X_tr, y_tr)
        y_pred_train = model.predict(X_tr)
        y_pred_test = model.predict(X_te)
        
        strategy_results_train.append([
            model_name,
            f1_score(y_tr, y_pred_train),
            accuracy_score(y_tr, y_pred_train),
            precision_score(y_tr, y_pred_train),
            recall_score(y_tr, y_pred_train)
        ])
        
        strategy_results_test.append([
            model_name,
            f1_score(y_test, y_pred_test),
            accuracy_score(y_test, y_pred_test),
            precision_score(y_test, y_pred_test),
            recall_score(y_test, y_pred_test)
        ])
    
    results_train[strategy_name] = pd.DataFrame(strategy_results_train, columns=['Model', 'F1 Score', 'Accuracy', 'Precision', 'Recall'])
    results_test[strategy_name] = pd.DataFrame(strategy_results_test, columns=['Model', 'F1 Score', 'Accuracy', 'Precision', 'Recall'])

print("\nTraining Data Results:")
for strategy_name, result_df in results_train.items():
    print(f"\nResults for {strategy_name} Sampling (Training Data):")
    print(result_df.sort_values(by='F1 Score', ascending=False).to_string(index=False))

print("\nTest Data Results:")
for strategy_name, result_df in results_test.items():
    print(f"\nResults for {strategy_name} Sampling (Test Data):")
    print(result_df.sort_values(by='F1 Score', ascending=False).to_string(index=False))

strategy_colors = {
    'Original': sns.color_palette("tab10")[0],
    'Upsample': sns.color_palette("tab10")[1],
    'Downsample': sns.color_palette("tab10")[2],
}

plt.figure(figsize=(12, 8))

for strategy_name, result_df in results_test.items():
    color = strategy_colors[strategy_name]
    plt.plot(result_df['Model'], result_df['F1 Score'], label=f"{strategy_name} (Test)", marker='o', linestyle='--', color=color)

for strategy_name, result_df in results_train.items():
    color = strategy_colors[strategy_name]
    plt.plot(result_df['Model'], result_df['F1 Score'], label=f"{strategy_name} (Train)", marker='o', linestyle='-', color=color)

plt.title('F1 Score Comparison Across Strategies (Train vs Test)')
plt.ylabel('F1 Score')
plt.xlabel('Models')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Training Data Results:
#
# Results for Downsample Sampling (Training Data):
#                Model  F1 Score  Accuracy  Precision   Recall
# HistGradientBoosting  1.000000  1.000000   1.000000 1.000000
#              XGBoost  1.000000  1.000000   1.000000 1.000000
#             LightGBM  1.000000  1.000000   1.000000 1.000000
#             CatBoost  1.000000  1.000000   1.000000 1.000000
#             Ensemble  1.000000  1.000000   1.000000 1.000000
#           BalancedRF  1.000000  1.000000   1.000000 1.000000
#         RandomForest  0.993377  0.993369   0.992063 0.994695
#   LogisticRegression  0.785812  0.791777   0.808989 0.763926
#
# Results for Original Sampling (Training Data):
#                Model  F1 Score  Accuracy  Precision   Recall
# HistGradientBoosting  1.000000  1.000000   1.000000 1.000000
#              XGBoost  1.000000  1.000000   1.000000 1.000000
#             Ensemble  1.000000  1.000000   1.000000 1.000000
#             CatBoost  0.994723  0.998870   0.989501 1.000000
#             LightGBM  0.975420  0.994633   0.952020 1.000000
#         RandomForest  0.937656  0.985876   0.884706 0.997347
#           BalancedRF  0.744324  0.926836   0.592767 1.000000
#   LogisticRegression  0.462796  0.814407   0.334515 0.750663
#
# Results for Upsample Sampling (Training Data):
#                Model  F1 Score  Accuracy  Precision   Recall
# HistGradientBoosting  1.000000  1.000000   1.000000 1.000000
#              XGBoost  1.000000  1.000000   1.000000 1.000000
#           BalancedRF  1.000000  1.000000   1.000000 1.000000
#             Ensemble  1.000000  1.000000   1.000000 1.000000
#             LightGBM  0.999689  0.999686   0.999378 1.000000
#             CatBoost  0.999689  0.999686   0.999689 0.999689
#         RandomForest  0.988282  0.988084   0.979823 0.996890
#   LogisticRegression  0.790712  0.792255   0.803273 0.778538
#
# Test Data Results:
#
# Results for Downsample Sampling (Test Data):
#                Model  F1 Score  Accuracy  Precision   Recall
#             CatBoost  0.684615  0.907449   0.536145 0.946809
#             LightGBM  0.671698  0.901806   0.520468 0.946809
#             Ensemble  0.671587  0.899549   0.514124 0.968085
# HistGradientBoosting  0.654135  0.896163   0.505814 0.925532
#              XGBoost  0.622837  0.876975   0.461538 0.957447
#           BalancedRF  0.619529  0.872460   0.453202 0.978723
#         RandomForest  0.613333  0.869074   0.446602 0.978723
#   LogisticRegression  0.416422  0.775395   0.287449 0.755319
#
# Results for Original Sampling (Test Data):
#                Model  F1 Score  Accuracy  Precision   Recall
#             CatBoost  0.790000  0.952596   0.745283 0.840426
# HistGradientBoosting  0.788571  0.958239   0.851852 0.734043
#              XGBoost  0.787234  0.954853   0.787234 0.787234
#             Ensemble  0.785340  0.953725   0.773196 0.797872
#             LightGBM  0.758621  0.944695   0.706422 0.819149
#         RandomForest  0.735751  0.942438   0.717172 0.755319
#           BalancedRF  0.679245  0.904063   0.526316 0.957447
#   LogisticRegression  0.451039  0.791196   0.312757 0.808511
#
# Results for Upsample Sampling (Test Data):
#                Model  F1 Score  Accuracy  Precision   Recall
#             CatBoost  0.821622  0.962754   0.835165 0.808511
# HistGradientBoosting  0.793478  0.957111   0.811111 0.776596
#             Ensemble  0.789744  0.953725   0.762376 0.819149
#           BalancedRF  0.775510  0.950339   0.745098 0.808511
#             LightGBM  0.760417  0.948081   0.744898 0.776596
#         RandomForest  0.746544  0.937923   0.658537 0.861702
#              XGBoost  0.732673  0.939052   0.685185 0.787234
#   LogisticRegression  0.430595  0.773138   0.293436 0.808511

# %% [markdown]
# #### Model Comparison Summary
#
# - **CatBoost** consistently outperforms other models on **test data** across all sampling strategies, achieving the **highest F1 scores** (up to 0.82 with upsampling).
#
# - **HistGradientBoosting**, **XGBoost**, and **Ensemble** models also perform well, particularly with original and upsampled data.
#
# - **LightGBM** and **RandomForest** show solid performance but slightly trail behind the top models.
#
# - **BalancedRF** benefits most from upsampling but underperforms with original and downsampled data.
#
# - **Logistic Regression** lags across all settings, confirming that more complex models handle the task better.
#
# > All models show perfect or near-perfect results on training data, indicating **clear overfitting**, likely due to the **limited dataset size**.

# %% [markdown]
# ### Features Removal Comparison

# %%
from tqdm import tqdm
from sklearn.metrics import f1_score

def compare_feature_sets(feature_sets, test_models):
    results = []

    for feat_set_name, feat_cols in tqdm(feature_sets.items(), desc='Feature sets'):
        X_sub = df_cleaned[feat_cols].copy()
        y_sub = df_cleaned['Hired']
        
        X_train, X_test, y_train, y_test = train_test_split(
            X_sub, y_sub, stratify=y_sub, test_size=0.2, random_state=42
        )
        
        bool_cols = X_train.select_dtypes(include='bool').columns
        non_bool_cols = X_train.columns.difference(bool_cols)
        
        X_train[bool_cols] = X_train[bool_cols].astype(int)
        X_test[bool_cols] = X_test[bool_cols].astype(int)
        
        scaler = StandardScaler()
        X_train[non_bool_cols] = scaler.fit_transform(X_train[non_bool_cols])
        X_test[non_bool_cols] = scaler.transform(X_test[non_bool_cols])
        
        for model_name, model_lambda in test_models.items():
            model = model_lambda()
            model.fit(X_train, y_train)
            y_pred_test = model.predict(X_test)
            y_pred_train = model.predict(X_train)
            f1_test = f1_score(y_test, y_pred_test)
            f1_train = f1_score(y_train, y_pred_train)
            results.append({
                'Feature Set': feat_set_name,
                'Model': model_name,
                'Train F1': f1_train,
                'Test F1': f1_test
            })

    results_df = pd.DataFrame(results)

    best_row = results_df.loc[results_df['Test F1'].idxmax()]
    print(f"\nBest performance:\nFeature Set: {best_row['Feature Set']}, Model: {best_row['Model']}, F1 Score: {best_row['Test F1']:.4f}")
    return results_df

# %%
feature_columns = [col for col in columns_to_keep if col != 'Hired']

feature_sets = {
    'general_similarity_score_cross': [col for col in feature_columns if col not in ['general_similarity_score', 'general_similarity_score_tfidf']],
    'general_similarity_score': [col for col in feature_columns if col not in ['general_similarity_score_tfidf', 'general_similarity_score_cross']],
    'general_similarity_score_tfidf': [col for col in feature_columns if col not in ['general_similarity_score', 'general_similarity_score_cross']],
    'None ':  [col for col in feature_columns if col not in ['general_similarity_score_tfidf', 'general_similarity_score', 'general_similarity_score_cross']], 
    'all': feature_columns,
    }

test_models = {
    "HistGradientBoostingClassifier":lambda: models['HistGradientBoosting'](),
    'CatBoost': lambda:   models['CatBoost'](),
    'Ensemble': lambda: VotingClassifier(
        estimators=[
            ('xgb', models['XGBoost']()),
            ('lgbm', models['LightGBM']()),
            ('cat', models['CatBoost']()),
            ('hist', models['HistGradientBoosting']()),
            ('brf', models['BalancedRF']())
        ],
        voting='soft'
    )
}

results_df = compare_feature_sets(feature_sets, test_models)
results_df
# Out:
# Feature sets: 100%|██████████| 5/5 [00:51<00:00, 10.38s/it]
# Best performance:
# Feature Set: general_similarity_score, Model: Ensemble, F1 Score: 0.8083
#                        Feature Set                           Model  Train F1  \
# 0   general_similarity_score_cross  HistGradientBoostingClassifier  1.000000
# 1   general_similarity_score_cross                        CatBoost  0.989501
# 2   general_similarity_score_cross                        Ensemble  0.997354
# 3         general_similarity_score  HistGradientBoostingClassifier  1.000000
# 4         general_similarity_score                        CatBoost  0.992105
# 5         general_similarity_score                        Ensemble  1.000000
# 6   general_similarity_score_tfidf  HistGradientBoostingClassifier  1.000000
# 7   general_similarity_score_tfidf                        CatBoost  0.985621
# 8   general_similarity_score_tfidf                        Ensemble  0.996037
# 9                            None   HistGradientBoostingClassifier  1.000000
# 10                           None                         CatBoost  0.976684
# 11                           None                         Ensemble  0.992105
# 12                             all  HistGradientBoostingClassifier  1.000000
# 13                             all                        CatBoost  0.994723
# 14                             all                        Ensemble  1.000000
#
#      Test F1
# 0   0.747253
# 1   0.748768
# 2   0.760976
# 3   0.791209
# 4   0.790000
# 5   0.808290
# 6   0.733333
# 7   0.753623
# 8   0.773869
# 9   0.764045
# 10  0.742857
# 11  0.753623
# 12  0.774566
# 13  0.790000
# 14  0.789474

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=results_df, x="Feature Set", y="Test F1", hue="Model")
plt.xticks(rotation=45, ha="right")
plt.ylim(0.8*min(results_df['Test F1']))
plt.title("F1 Scores by Feature Set and Model")
plt.tight_layout()
plt.legend(title="Model")
plt.grid(axis='y')

plt.show()

# %% [markdown]
# #### Feature Set Comparison Summary
#
# - **`general_similarity_score`** yields the **best performance** across models, especially for the **Ensemble model (F1 = 0.808)**, indicating it is the most informative feature.
#
# - This suggests that using a **SentenceTransformer encoder** to represent candidate and job texts, then computing their **semantic similarity**, captures meaningful relationships **better than TF-IDF**-based similarity (`general_similarity_score_tfidf`) or cross-similarity (`general_similarity_score_cross`).
#
# - Including **all three features** does **not improve performance**, likely because they all serve a **similar purpose**—measuring textual alignment between candidate profiles and job descriptions. The added redundancy may not add new information but could introduce noise.
#
# > We will use only `general_similarity_score` (semantic similarity using embeddings) for optimal and efficient model performance.

# %%
feature_sets = {
    "base_attributes": [
        "Sex_int",
        "Protected category",
        "Overall",
        "Technical Skills",
        "Standing/Position",
        "Comunication",
        "Maturity",
        "Dynamism",
        "Mobility",
        "English",
        "Italian Residence",
        "European Residence",
        "Age Range_int",
        "Years Experience_int",
        "Years Experience.1_int",
        "Current Ral",
        "Expected Ral",
        "Minimum Ral",
        "Ral Maximum",
        "Study Level_int",
        "Study Title_int",
        "number_of_searches",
    ],
    "custom_scores": [
        "experience_match_score",
        "current_salary_fit_score",
        "expected_salary_fit_score",
        "study_title_score",
        "professional_similarity_score",
        "study_area_score",
        "general_similarity_score",
        "Distance Residence - Akkodis HQ",
        "Distance Residence - Assumption HQ",
    ],
    "base_attributes_with_essential_custom_scores": [
        "Sex_int",
        "Protected category",
        "Overall",
        "Technical Skills",
        "Standing/Position",
        "Comunication",
        "Maturity",
        "Dynamism",
        "Mobility",
        "English",
        "Italian Residence",
        "European Residence",
        "Age Range_int",
        "number_of_searches",
        "experience_match_score",
        "current_salary_fit_score",
        "expected_salary_fit_score",
        "study_title_score",
        "professional_similarity_score",
        "study_area_score",
        "general_similarity_score",
        "Distance Residence - Akkodis HQ",
        "Distance Residence - Assumption HQ",
    ],
    "custom_scores_with_essential_base_attributes": [
        "Sex_int",
        "Protected category",
        "Overall",
        "Technical Skills",
        "Standing/Position",
        "Comunication",
        "Maturity",
        "Dynamism",
        "Mobility",
        "English",
        "Italian Residence",
        "European Residence",
        "Age Range_int",
        "number_of_searches",
        "study_area_score",
        "general_similarity_score",
        "Distance Residence - Akkodis HQ",
        "Distance Residence - Assumption HQ",
        "Years Experience_int",
        "Years Experience.1_int",
        "Current Ral",
        "Expected Ral",
        "Minimum Ral",
        "Ral Maximum",
        "Study Level_int",
        "Study Title_int",
    ],
    "all": [
        "Sex_int",
        "Protected category",
        "Overall",
        "Technical Skills",
        "Standing/Position",
        "Comunication",
        "Maturity",
        "Dynamism",
        "Mobility",
        "English",
        "Italian Residence",
        "European Residence",
        "Age Range_int",
        "experience_match_score",
        "Years Experience_int",
        "Years Experience.1_int",
        "current_salary_fit_score",
        "Current Ral",
        "Expected Ral",
        "Minimum Ral",
        "Ral Maximum",
        "expected_salary_fit_score",
        "study_title_score",
        "Study Level_int",
        "Study Title_int",
        "professional_similarity_score",
        "study_area_score",
        "general_similarity_score",
        "number_of_searches",
        "Distance Residence - Akkodis HQ",
        "Distance Residence - Assumption HQ",
    ],
}
results_df = compare_feature_sets(feature_sets, test_models)
results_df
# Out:
# Feature sets: 100%|██████████| 5/5 [00:49<00:00,  9.81s/it]
# Best performance:
# Feature Set: custom_scores_with_essential_base_attributes, Model: Ensemble, F1 Score: 0.8103
#                                      Feature Set  \
# 0                                base_attributes
# 1                                base_attributes
# 2                                base_attributes
# 3                                  custom_scores
# 4                                  custom_scores
# 5                                  custom_scores
# 6   base_attributes_with_essential_custom_scores
# 7   base_attributes_with_essential_custom_scores
# 8   base_attributes_with_essential_custom_scores
# 9   custom_scores_with_essential_base_attributes
# 10  custom_scores_with_essential_base_attributes
# 11  custom_scores_with_essential_base_attributes
# 12                                           all
# 13                                           all
# 14                                           all
#
#                              Model  Train F1   Test F1
# 0   HistGradientBoostingClassifier  0.996005  0.604938
# 1                         CatBoost  0.928571  0.716279
# 2                         Ensemble  0.970399  0.703518
# 3   HistGradientBoostingClassifier  0.943978  0.513514
# 4                         CatBoost  0.877480  0.525822
# 5                         Ensemble  0.954430  0.556701
# 6   HistGradientBoostingClassifier  1.000000  0.784091
# 7                         CatBoost  0.989501  0.784314
# 8                         Ensemble  0.998675  0.808081
# 9   HistGradientBoostingClassifier  1.000000  0.774566
# 10                        CatBoost  0.979221  0.800000
# 11                        Ensemble  0.998675  0.810256
# 12  HistGradientBoostingClassifier  1.000000  0.791209
# 13                        CatBoost  0.992105  0.790000
# 14                        Ensemble  1.000000  0.808290

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=results_df, x="Feature Set", y="Test F1", hue="Model")
plt.xticks(rotation=45, ha="right")
plt.ylim(0.8*min(results_df['Test F1']))
plt.title("F1 Scores by Feature Set and Model")
plt.tight_layout()
plt.legend(title="Model")
plt.grid(axis='y')

plt.show()

# %% [markdown]
# #### Feature Set Comparison Summary
#
# The best performance is achieved with the **`custom_scores_with_essential_base_attributes`** feature set using the **Ensemble model**, reaching a **Test F1 Score of 0.8103**.
#
# Summary of all tested feature sets:
#
# - **base_attributes**
#   Includes demographic and general profile data such as sex, residence, experience, education, and language skills.
#   Lower performance (max Test F1 ≈ 0.716), as it lacks direct indicators of job-candidate fit.
#
# - **custom_scores**
#   Contains match-related scores between candidate and job attributes (e.g., salary fit, similarity scores, distances).
#   Performance is weaker (max Test F1 ≈ 0.557), likely due to missing foundational profile context.
#
# - **base_attributes_with_essential_custom_scores**
#   Adds essential custom scores (e.g., general similarity, salary fit) to the base profile features.
#   Strong improvement (Test F1 ≈ 0.808), showing benefit of combining foundational and match-specific data.
#
# - **custom_scores_with_essential_base_attributes**
#   Focuses on custom match scores with key supporting base attributes (e.g., experience, salary, study level).
#   **Best performance** (Test F1 = 0.8103), suggesting optimal balance of candidate profile and job fit signals.
#
# - **all**
#   Combines all available features.
#   Performance (Test F1 ≈ 0.808) does not exceed the best set, likely due to **redundant concepts** (e.g., overlapping indicators for salary, experience, similarity) that introduce noise.
#
# > **Conclusion:** Carefully selected combinations of essential base features and custom match scores outperform using all features. Including all available data does not necessarily yield better results due to repeated or overlapping information.

# %% [markdown]
# ### Sampling Techniques

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import VotingClassifier

from imblearn.over_sampling import SMOTE, ADASYN, BorderlineSMOTE, SVMSMOTE
from imblearn.under_sampling import RandomUnderSampler


df = df_cleaned[feature_sets['custom_scores_with_essential_base_attributes']+['Hired']].copy()
X = df.drop(columns=['Hired'])
y = df['Hired']

bool_cols = X.select_dtypes(include='bool').columns
non_bool_cols = X.columns.difference(bool_cols)

X[bool_cols] = X[bool_cols].astype(int)

scaler = StandardScaler()
X[non_bool_cols] = scaler.fit_transform(X[non_bool_cols])

X_train, X_test, y_train, y_test = train_test_split(
    X, y, stratify=y, test_size=0.2, random_state=42
)

imputer = SimpleImputer(strategy='mean')
X_train_imputed = pd.DataFrame(imputer.fit_transform(X_train), columns=X_train.columns)
X_test_imputed = pd.DataFrame(imputer.transform(X_test), columns=X_test.columns)

X_orig, y_orig = X_train_imputed, y_train

minority_count = sum(y_orig == 1)
majority_count = sum(y_orig == 0)

test_models = {
    'CatBoost': lambda: CatBoostClassifier(
        auto_class_weights='Balanced', silent=True, random_state=42,
        l2_leaf_reg=3, iterations=500, depth=6, learning_rate=0.05
    ),
    'Ensemble': lambda: VotingClassifier(
        estimators=[
            ('xgb', models['XGBoost']()),
            ('lgbm', models['LightGBM']()),
            ('cat', models['CatBoost']()),
            ('hist', models['HistGradientBoosting']()),
            ('brf', models['BalancedRF']())
        ],
        voting='soft'
    )
}


smote_ratios = [0.25, 0.5, 0.75, 1.0]

resampled_datasets = {}

resampled_datasets['Original'] = (X_orig, y_orig)

for ratio in smote_ratios:
    name = f'SMOTE_{int(ratio*100)}%'
    smote = SMOTE(sampling_strategy=ratio, random_state=42)
    X_res, y_res = smote.fit_resample(X_orig, y_orig)
    resampled_datasets[name] = (X_res, y_res)

for ratio in smote_ratios:
    name = f'ADASYN_{int(ratio*100)}%'
    adasyn = ADASYN(sampling_strategy=ratio, random_state=42)
    X_res, y_res = adasyn.fit_resample(X_orig, y_orig)
    resampled_datasets[name] = (X_res, y_res)

for ratio in smote_ratios:
    name = f'BorderlineSMOTE_{int(ratio*100)}%'
    bl_smote = BorderlineSMOTE(sampling_strategy=ratio, random_state=42)
    X_res, y_res = bl_smote.fit_resample(X_orig, y_orig)
    resampled_datasets[name] = (X_res, y_res)

for ratio in smote_ratios:
    name = f'SVMSMOTE_{int(ratio*100)}%'
    svm_smote = SVMSMOTE(sampling_strategy=ratio, random_state=42)
    X_res, y_res = svm_smote.fit_resample(X_orig, y_orig)
    resampled_datasets[name] = (X_res, y_res)

resampled_datasets['Downsampling'] = RandomUnderSampler(random_state=42).fit_resample(X_orig, y_orig)

results = []

for strategy_name, (X_resampled, y_resampled) in tqdm(resampled_datasets.items(), desc='Training...'):
    for model_name, model_lambda in test_models.items():
        model = model_lambda()
        model.fit(X_resampled, y_resampled)
        y_pred_test = model.predict(X_test_imputed)
        y_pred_train = model.predict(X_resampled)
        f1_test = f1_score(y_test, y_pred_test)
        f1_train = f1_score(y_resampled, y_pred_train)
        results.append({
            'Resampling': strategy_name,
            'Model': model_name,
            'Train F1': f1_train,
            'Test F1': f1_test
        })

results_df = pd.DataFrame(results)
results_df
# Out:
# Training...: 100%|██████████| 18/18 [03:10<00:00, 10.57s/it]
#               Resampling     Model  Train F1   Test F1
# 0               Original  CatBoost  0.984334  0.775510
# 1               Original  Ensemble  0.998675  0.814433
# 2              SMOTE_25%  CatBoost  0.994962  0.818182
# 3              SMOTE_25%  Ensemble  0.999367  0.812500
# 4              SMOTE_50%  CatBoost  0.998736  0.825397
# 5              SMOTE_50%  Ensemble  0.999684  0.827225
# 6              SMOTE_75%  CatBoost  0.999157  0.777778
# 7              SMOTE_75%  Ensemble  1.000000  0.802083
# 8             SMOTE_100%  CatBoost  0.999368  0.800000
# 9             SMOTE_100%  Ensemble  1.000000  0.817204
# 10            ADASYN_25%  CatBoost  0.995222  0.834171
# 11            ADASYN_25%  Ensemble  0.997947  0.791667
# 12            ADASYN_50%  CatBoost  0.998383  0.785340
# 13            ADASYN_50%  Ensemble  0.999676  0.797872
# 14            ADASYN_75%  CatBoost  0.999161  0.800000
# 15            ADASYN_75%  Ensemble  1.000000  0.808511
# 16           ADASYN_100%  CatBoost  0.999375  0.769231
# 17           ADASYN_100%  Ensemble  1.000000  0.812500
# 18   BorderlineSMOTE_25%  CatBoost  0.995589  0.808081
# 19   BorderlineSMOTE_25%  Ensemble  0.999367  0.816754
# 20   BorderlineSMOTE_50%  CatBoost  0.997788  0.814815
# 21   BorderlineSMOTE_50%  Ensemble  1.000000  0.823529
# 22   BorderlineSMOTE_75%  CatBoost  0.999367  0.813187
# 23   BorderlineSMOTE_75%  Ensemble  1.000000  0.819149
# 24  BorderlineSMOTE_100%  CatBoost  0.999526  0.819672
# 25  BorderlineSMOTE_100%  Ensemble  1.000000  0.838710
# 26          SVMSMOTE_25%  CatBoost  0.996217  0.808290
# 27          SVMSMOTE_25%  Ensemble  1.000000  0.808290
# 28          SVMSMOTE_50%  CatBoost  0.998419  0.789474
# 29          SVMSMOTE_50%  Ensemble  1.000000  0.812500
# 30          SVMSMOTE_75%  CatBoost  0.999157  0.797814
# 31          SVMSMOTE_75%  Ensemble  1.000000  0.810811
# 32         SVMSMOTE_100%  CatBoost  0.999684  0.804348
# 33         SVMSMOTE_100%  Ensemble  1.000000  0.802198
# 34          Downsampling  CatBoost  1.000000  0.661710
# 35          Downsampling  Ensemble  1.000000  0.649819

# %%
min_f1 = results_df['Test F1'].min()

plt.figure(figsize=(16, 8))
sns.barplot(
    data=results_df,
    x='Resampling',
    y='Test F1',
    hue='Model',
    palette='Set2'
)
plt.title('F1 Score of CatBoost and Ensemble Models Across Resampling Techniques & Ratios')
plt.xticks(rotation=90)
plt.ylabel('F1 Score')
plt.ylim(bottom=0.95 * min_f1)
plt.xlabel('Resampling Strategy')
plt.legend(title='Model')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Resampling Strategy Comparison Summary
#
# This experiment compared various resampling techniques to mitigate class imbalance, evaluating their impact on **CatBoost** and **Ensemble** models based on Train and Test F1 scores.
#
# ##### Best Performance
# - **Top Result:** `BorderlineSMOTE_100%` with **Ensemble** (Test F1 = **0.8387**)
#
# ##### Final Choice: `SMOTE_50%`
# Although `BorderlineSMOTE_100%` slightly outperformed other methods, the **improvement over `SMOTE_50%` is marginal**. At the same time, `SMOTE_50%` offers the following advantages:
#
# - **Strong performance with both models**:
#   - CatBoost F1 = **0.8254**
#   - Ensemble F1 = **0.8272**
# - **More efficient**: It avoids generating an excessive number of synthetic samples.
# - **Better balance** between **performance and computational simplicity**.
#
# ##### Key Observations
#
# - **SMOTE_50%** achieves high F1 scores with minimal added complexity.
# - **BorderlineSMOTE** performs slightly better but at the cost of more synthetic data generation.
# - **ADASYN** and **SVMSMOTE** also show decent results but do not clearly outperform SMOTE.
# - **Downsampling** significantly harms generalization despite perfect training F1.
#
# > 💡 **Conclusion:**
# We select **SMOTE with 50% ratio** as the optimal resampling strategy. It provides a **strong performance gain** without overcomplicating the training process or risking overfitting through excessive synthetic data.

# %% [markdown]
# ### Fairness Metrics

# %%
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

from fairlearn.metrics import (
    MetricFrame,
    demographic_parity_difference,
    equalized_odds_difference
)
from sklearn.metrics import precision_score, recall_score
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

df = df_cleaned.copy()

protected_attributes = [
    'Sex_int', 'Protected category', 'Age Range_int',
    'Italian Residence', 'European Residence'
]

df = df.dropna(subset=protected_attributes).reset_index(drop=True)

X = df.drop(columns=['Hired'])[feature_sets['custom_scores_with_essential_base_attributes']]
y = df['Hired']

bool_cols = X.select_dtypes(include='bool').columns
non_bool_cols = X.columns.difference(bool_cols)

X[bool_cols] = X[bool_cols].astype(int)
scaler = StandardScaler()
X[non_bool_cols] = scaler.fit_transform(X[non_bool_cols])

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

imputer = SimpleImputer(strategy='mean')
X_train_imp = pd.DataFrame(imputer.fit_transform(X_train), columns=X.columns)
X_test_imp = pd.DataFrame(imputer.transform(X_test), columns=X.columns)

svm_smote = SMOTE(sampling_strategy=0.5, random_state=42)
X_res, y_res = svm_smote.fit_resample(X_train_imp, y_train)

majority_count = (y_res == 0).sum()
minority_count = (y_res == 1).sum()

catboost_model = CatBoostClassifier(
    auto_class_weights='Balanced', silent=True, random_state=42,
    l2_leaf_reg=3, iterations=500, depth=6, learning_rate=0.05
)

ensemble_model = VotingClassifier(
    estimators=[
            ('xgb', models['XGBoost']()),
            ('lgbm', models['LightGBM']()),
            ('cat', models['CatBoost']()),
            ('hist', models['HistGradientBoosting']()),
            ('brf', models['BalancedRF']())
    ],
    voting='soft'
)

catboost_model.fit(X_res, y_res)
ensemble_model.fit(X_res, y_res)

y_pred_cat = catboost_model.predict(X_test_imp)
y_pred_ens = ensemble_model.predict(X_test_imp)

performance_results = []
fairness_results = []

for model_name, y_pred in [('CatBoost', y_pred_cat), ('Ensemble', y_pred_ens)]:
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    
    performance_results.append({
        'Model': model_name,
        'Precision': precision,
        'Recall': recall
    })
    
    for attr in protected_attributes:
        sensitive_features_test = dataset.loc[X_test.index, attr]
        dp_diff = demographic_parity_difference(
            y_true=y_test,
            y_pred=y_pred,
            sensitive_features=sensitive_features_test
        )
    
        eo_diff = equalized_odds_difference(
            y_true=y_test,
            y_pred=y_pred,
            sensitive_features=sensitive_features_test
        )
        
        fairness_results.append({
            'Model': model_name, 
            'Attribute': attr,
            'Demographic Parity Diff': dp_diff,
            'Equalized Odds Diff': eo_diff
        })


performance_df = pd.DataFrame(performance_results)
fairness_df = pd.DataFrame(fairness_results)

long_perf_df = pd.melt(
    performance_df,
    id_vars=['Model'],
    value_vars=['Precision', 'Recall'],
    var_name='Metric',
    value_name='Score'
)

import matplotlib.pyplot as plt
import seaborn as sns

for attr in protected_attributes:
    subset = fairness_df[fairness_df['Attribute'] == attr]
    
    plt.figure(figsize=(10, 5))
    sns.barplot(data=subset, x='Model', y='Demographic Parity Diff', palette='Set3')
    plt.title(f"Demographic Parity Difference for {attr}")
    plt.axhline(0, linestyle='--', color='gray')
    plt.ylabel("Difference (Ideal = 0)")
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(10, 5))
    sns.barplot(data=subset, x='Model', y='Equalized Odds Diff', palette='Set1')
    plt.title(f"Equalized Odds Difference for {attr}")
    plt.axhline(0, linestyle='--', color='gray')
    plt.ylabel("Difference (Ideal = 0)")
    plt.tight_layout()
    plt.show()

    for model_name, y_pred in [('CatBoost', y_pred_cat), ('Ensemble', y_pred_ens)]:
        sensitive_features_test = df.loc[X_test.index, attr]

        mf = MetricFrame(
            metrics={'precision': precision_score, 'recall': recall_score},
            y_true=y_test,
            y_pred=y_pred,
            sensitive_features=sensitive_features_test
        )

        per_group_metrics = pd.DataFrame({
            'Group': mf.by_group.index,
            'Precision': mf.by_group['precision'].values,
            'Recall': mf.by_group['recall'].values
        })
        per_group_metrics_melted = per_group_metrics.melt(
            id_vars='Group', var_name='Metric', value_name='Score'
        )
        plt.figure(figsize=(12, 6))
        sns.barplot(data=per_group_metrics.melt(id_vars='Group'), x='Group', y='value', hue='variable', palette='pastel')
        plt.title(f'Precision and Recall by Group for {attr} ({model_name})')
        plt.ylabel('Score')
        plt.ylim(0.8 * per_group_metrics_melted['Score'].min(), 1)
        plt.legend(title='')
        plt.tight_layout()
        plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

fairness_long = fairness_df.melt(
    id_vars=['Model', 'Attribute'],
    value_vars=['Demographic Parity Diff', 'Equalized Odds Diff'],
    var_name='Fairness Metric',
    value_name='Score'
)

plt.figure(figsize=(14, 7))
sns.barplot(
    data=fairness_long,
    x='Attribute',
    y='Score',
    hue='Model',
    palette='Set2',
    ci=None,
    dodge=True
)
plt.title("Fairness Metrics (Demographic Parity & Equalized Odds Differences) Across Attributes")
plt.axhline(0, linestyle='--', color='gray')
plt.ylabel("Difference (Ideal = 0)")
plt.xticks(rotation=45)
plt.legend(title='Model')
plt.tight_layout()
plt.show()

from fairlearn.metrics import MetricFrame
from sklearn.metrics import precision_score, recall_score

for attr in protected_attributes:
    plt.figure(figsize=(14, 6))
    
    combined_data = []
    
    for model_name, y_pred in [('CatBoost', y_pred_cat), ('Ensemble', y_pred_ens)]:
        sensitive_features_test = df.loc[X_test.index, attr]
        
        mf = MetricFrame(
            metrics={'Precision': precision_score, 'Recall': recall_score},
            y_true=y_test,
            y_pred=y_pred,
            sensitive_features=sensitive_features_test
        )
        
        per_group_metrics = mf.by_group.reset_index()
        per_group_metrics['Model'] = model_name
        combined_data.append(per_group_metrics)
    
    combined_df = pd.concat(combined_data)
    
    combined_melted = combined_df.melt(
        id_vars=[attr, 'Model'],
        value_vars=['Precision', 'Recall'],
        var_name='Metric',
        value_name='Score'
    )
    
    combined_melted['Model_Metric'] = combined_melted['Model'] + ' | ' + combined_melted['Metric']
    
    sns.barplot(
        data=combined_melted,
        x=attr,
        y='Score',
        hue='Model_Metric',
        palette='Set2'
    )
    
    plt.title(f'Precision and Recall by Group for {attr}')
    plt.ylim(0, 1)
    plt.ylabel('Score')
    plt.xlabel(attr)
    plt.xticks(rotation=45)
    plt.legend(title='Model | Metric', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %%
fairness_df
# Out:
#       Model           Attribute  Demographic Parity Diff  Equalized Odds Diff
# 0  CatBoost             Sex_int                 0.019349             0.099415
# 1  CatBoost  Protected category                 0.117179             0.808511
# 2  CatBoost       Age Range_int                 0.058647             0.175000
# 3  CatBoost   Italian Residence                 0.029109             0.195652
# 4  CatBoost  European Residence                 0.005327             0.808511
# 5  Ensemble             Sex_int                 0.003559             0.016465
# 6  Ensemble  Protected category                 0.113766             0.829787
# 7  Ensemble       Age Range_int                 0.069173             0.177606
# 8  Ensemble   Italian Residence                 0.048947             0.173913
# 9  Ensemble  European Residence                 0.114155             0.829787

# %%
performance_df
# Out:
#       Model  Precision    Recall
# 0  CatBoost   0.737864  0.808511
# 1  Ensemble   0.780000  0.829787

# %% [markdown]
# #### Preliminary Analysis of Model Performance and Fairness with Protected Attributes
#
# ##### Predictive Performance
# - The **Ensemble model** slightly outperforms **CatBoost** in both precision (0.78 vs 0.74) and recall (0.83 vs 0.81), indicating stronger overall predictive ability when protected attributes are included.
#
# ##### Fairness Metrics
# - **Sex_int:** Fairly low demographic parity difference (~0.02 CatBoost, ~0.004 Ensemble) and moderate equalized odds difference, indicating relatively balanced treatment across sex groups.
# - **Protected category:** High demographic parity (~0.11-0.12) and very high equalized odds difference (~0.81-0.83), signaling significant bias and error disparity.
# - **Age Range_int:** Moderate demographic parity difference (~0.06-0.07) and moderate equalized odds difference (~0.17-0.18), showing some fairness concerns but less severe than protected category.
# - **Italian Residence:** Low to moderate demographic parity (~0.03-0.05) and moderate equalized odds difference (~0.17-0.20), suggesting some bias potentially due to geographic factors.
# - **European Residence:** Low demographic parity for CatBoost (~0.005) but higher for Ensemble (~0.11), with very high equalized odds difference (~0.81-0.83), due to limited or imbalanced subgroup data causing fairness issues.
#
# ##### Next Steps
# To address these fairness challenges, we will experiment with **removing protected attributes** from the training data. This approach aims to test whether excluding sensitive information helps reduce bias and leads to fairer model behavior without substantially sacrificing predictive performance.

# %% [markdown]
# ### Removing Protected Atttributes

# %%
from catboost import CatBoostClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from fairlearn.metrics import (
    MetricFrame,
    demographic_parity_difference,
    equalized_odds_difference
)
from imblearn.over_sampling import SVMSMOTE
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df = df_cleaned.copy()

protected_attributes = [
    'Sex_int', 'Protected category', 'Age Range_int',
    'Italian Residence', 'European Residence'
]

df = df.dropna(subset=protected_attributes).reset_index(drop=True)

feature_sets_dict = {
    'With Protected': feature_sets['custom_scores_with_essential_base_attributes'],
    'Without Protected': list(set(feature_sets['custom_scores_with_essential_base_attributes']) - set(protected_attributes))
}

results = []
pergroup_all = []

for setting_label, features in feature_sets_dict.items():
    X = df[features].copy()
    y = df['Hired']

    bool_cols = X.select_dtypes(include='bool').columns
    non_bool_cols = X.columns.difference(bool_cols)
    X[bool_cols] = X[bool_cols].astype(int)
    scaler = StandardScaler()
    X[non_bool_cols] = scaler.fit_transform(X[non_bool_cols])

    X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

    imputer = SimpleImputer(strategy='mean')
    X_train_imp = pd.DataFrame(imputer.fit_transform(X_train), columns=X.columns)
    X_test_imp = pd.DataFrame(imputer.transform(X_test), columns=X.columns)

    X_res, y_res = SMOTE(sampling_strategy=0.5, random_state=42).fit_resample(X_train_imp, y_train)

    cat_model = models['CatBoost']()
    ens_model = models['Ensemble']()

    cat_model.fit(X_res, y_res)
    ens_model.fit(X_res, y_res)

    y_pred_cat = cat_model.predict(X_test_imp)
    y_pred_ens = ens_model.predict(X_test_imp)

    for model_name, y_pred in [('CatBoost', y_pred_cat), ('Ensemble', y_pred_ens)]:
        precision = precision_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)

        results.append({
            'Setting': setting_label,
            'Model': model_name,
            'Precision': precision,
            'Recall': recall,
            'F1 Score': f1
        })

        for attr in protected_attributes:
            sensitive_features_test = df.loc[X_test.index, attr]

            dp_diff = demographic_parity_difference(y_test, y_pred, sensitive_features=sensitive_features_test)
            eo_diff = equalized_odds_difference(y_test, y_pred, sensitive_features=sensitive_features_test)

            results.append({
                'Setting': setting_label,
                'Model': model_name,
                'Attribute': attr,
                'Metric': 'Demographic Parity Diff',
                'Score': dp_diff
            })
            results.append({
                'Setting': setting_label,
                'Model': model_name,
                'Attribute': attr,
                'Metric': 'Equalized Odds Diff',
                'Score': eo_diff
            })

            mf = MetricFrame(
                metrics={'precision': precision_score, 'recall': recall_score},
                y_true=y_test,
                y_pred=y_pred,
                sensitive_features=sensitive_features_test
            )

            pergroup_all.append(pd.DataFrame({
                'Setting': setting_label,
                'Model': model_name,
                'Attribute': attr,
                'Group': mf.by_group.index,
                'Precision': mf.by_group['precision'].values,
                'Recall': mf.by_group['recall'].values
            }))

performance_df = pd.DataFrame([r for r in results if 'F1 Score' in r])
fairness_df = pd.DataFrame([r for r in results if 'Attribute' in r])
pergroup_df = pd.concat(pergroup_all, ignore_index=True)

# %%
performance_df
# Out:
#              Setting     Model  Precision    Recall  F1 Score
# 0     With Protected  CatBoost   0.737864  0.808511  0.771574
# 1     With Protected  Ensemble   0.780000  0.829787  0.804124
# 2  Without Protected  CatBoost   0.722772  0.776596  0.748718
# 3  Without Protected  Ensemble   0.710280  0.808511  0.756219

# %%
fairness_df
# Out:
#               Setting     Model           Attribute                   Metric  \
# 0      With Protected  CatBoost             Sex_int  Demographic Parity Diff
# 1      With Protected  CatBoost             Sex_int      Equalized Odds Diff
# 2      With Protected  CatBoost  Protected category  Demographic Parity Diff
# 3      With Protected  CatBoost  Protected category      Equalized Odds Diff
# 4      With Protected  CatBoost       Age Range_int  Demographic Parity Diff
# 5      With Protected  CatBoost       Age Range_int      Equalized Odds Diff
# 6      With Protected  CatBoost   Italian Residence  Demographic Parity Diff
# 7      With Protected  CatBoost   Italian Residence      Equalized Odds Diff
# 8      With Protected  CatBoost  European Residence  Demographic Parity Diff
# 9      With Protected  CatBoost  European Residence      Equalized Odds Diff
# 10     With Protected  Ensemble             Sex_int  Demographic Parity Diff
# 11     With Protected  Ensemble             Sex_int      Equalized Odds Diff
# 12     With Protected  Ensemble  Protected category  Demographic Parity Diff
# 13     With Protected  Ensemble  Protected category      Equalized Odds Diff
# 14     With Protected  Ensemble       Age Range_int  Demographic Parity Diff
# 15     With Protected  Ensemble       Age Range_int      Equalized Odds Diff
# 16     With Protected  Ensemble   Italian Residence  Demographic Parity Diff
# 17     With Protected  Ensemble   Italian Residence      Equalized Odds Diff
# 18     With Protected  Ensemble  European Residence  Demographic Parity Diff
# 19     With Protected  Ensemble  European Residence      Equalized Odds Diff
# 20  Without Protected  CatBoost             Sex_int  Demographic Parity Diff
# 21  Without Protected  CatBoost             Sex_int      Equalized Odds Diff
# 22  Without Protected  CatBoost  Protected category  Demographic Parity Diff
# 23  Without Protected  CatBoost  Protected category      Equalized Odds Diff
# 24  Without Protected  CatBoost       Age Range_int  Demographic Parity Diff
# 25  Without Protected  CatBoost       Age Range_int      Equalized Odds Diff
# 26  Without Protected  CatBoost   Italian Residence  Demographic Parity Diff
# 27  Without Protected  CatBoost   Italian Residence      Equalized Odds Diff
# 28  Without Protected  CatBoost  European Residence  Demographic Parity Diff
# 29  Without Protected  CatBoost  European Residence      Equalized Odds Diff
# 30  Without Protected  Ensemble             Sex_int  Demographic Parity Diff
# 31  Without Protected  Ensemble             Sex_int      Equalized Odds Diff
# 32  Without Protected  Ensemble  Protected category  Demographic Parity Diff
# 33  Without Protected  Ensemble  Protected category      Equalized Odds Diff
# 34  Without Protected  Ensemble       Age Range_int  Demographic Parity Diff
# 35  Without Protected  Ensemble       Age Range_int      Equalized Odds Diff
# 36  Without Protected  Ensemble   Italian Residence  Demographic Parity Diff
# 37  Without Protected  Ensemble   Italian Residence      Equalized Odds Diff
# 38  Without Protected  Ensemble  European Residence  Demographic Parity Diff
# 39  Without Protected  Ensemble  European Residence      Equalized Odds Diff
#
#        Score
# 0   0.067092
# 1   0.060807
# 2   0.117984
# 3   0.817204
# 4   0.178101
# 5   0.500000
# 6   0.059760
# 7   0.195652
# 8   0.118255
# 9   0.808511
# 10  0.078568
# 11  0.134881
# 12  0.030069
# 13  0.172043
# 14  0.176297
# 15  0.333333
# 16  0.077365
# 17  0.336957
# 18  0.114811
# 19  0.829787
# 20  0.069889
# 21  0.025080
# 22  0.115693
# 23  0.784946
# 24  0.136620
# 25  0.333333
# 26  0.099760
# 27  0.282609
# 28  0.115959
# 29  0.776596
# 30  0.083340
# 31  0.037523
# 32  0.122566
# 33  0.817204
# 34  0.136620
# 35  0.333333
# 36  0.106946
# 37  0.315217
# 38  0.122847
# 39  0.808511

# %%
pergroup_df
# Out:
#               Setting     Model           Attribute  Group  Precision  \
# 0      With Protected  CatBoost             Sex_int      0   0.793103
# 1      With Protected  CatBoost             Sex_int      1   0.716216
# 2      With Protected  CatBoost  Protected category      0   0.737864
# 3      With Protected  CatBoost  Protected category      1   0.000000
# 4      With Protected  CatBoost       Age Range_int      0   0.600000
# 5      With Protected  CatBoost       Age Range_int      1   0.666667
# 6      With Protected  CatBoost       Age Range_int      2   0.702703
# 7      With Protected  CatBoost       Age Range_int      3   0.842105
# 8      With Protected  CatBoost       Age Range_int      4   0.769231
# 9      With Protected  CatBoost       Age Range_int      5   0.777778
# 10     With Protected  CatBoost       Age Range_int      6   0.727273
# 11     With Protected  CatBoost   Italian Residence      0   0.666667
# 12     With Protected  CatBoost   Italian Residence      1   0.740000
# 13     With Protected  CatBoost  European Residence      0   0.000000
# 14     With Protected  CatBoost  European Residence      1   0.737864
# 15     With Protected  Ensemble             Sex_int      0   0.833333
# 16     With Protected  Ensemble             Sex_int      1   0.757143
# 17     With Protected  Ensemble  Protected category      0   0.777778
# 18     With Protected  Ensemble  Protected category      1   1.000000
# 19     With Protected  Ensemble       Age Range_int      0   0.800000
# 20     With Protected  Ensemble       Age Range_int      1   0.666667
# 21     With Protected  Ensemble       Age Range_int      2   0.787879
# 22     With Protected  Ensemble       Age Range_int      3   0.809524
# 23     With Protected  Ensemble       Age Range_int      4   0.818182
# 24     With Protected  Ensemble       Age Range_int      5   0.777778
# 25     With Protected  Ensemble       Age Range_int      6   0.750000
# 26     With Protected  Ensemble   Italian Residence      0   0.500000
# 27     With Protected  Ensemble   Italian Residence      1   0.785714
# 28     With Protected  Ensemble  European Residence      0   0.000000
# 29     With Protected  Ensemble  European Residence      1   0.780000
# 30  Without Protected  CatBoost             Sex_int      0   0.724138
# 31  Without Protected  CatBoost             Sex_int      1   0.722222
# 32  Without Protected  CatBoost  Protected category      0   0.722772
# 33  Without Protected  CatBoost  Protected category      1   0.000000
# 34  Without Protected  CatBoost       Age Range_int      0   0.500000
# 35  Without Protected  CatBoost       Age Range_int      1   0.545455
# 36  Without Protected  CatBoost       Age Range_int      2   0.750000
# 37  Without Protected  CatBoost       Age Range_int      3   0.764706
# 38  Without Protected  CatBoost       Age Range_int      4   0.800000
# 39  Without Protected  CatBoost       Age Range_int      5   0.875000
# 40  Without Protected  CatBoost       Age Range_int      6   0.727273
# 41  Without Protected  CatBoost   Italian Residence      0   1.000000
# 42  Without Protected  CatBoost   Italian Residence      1   0.720000
# 43  Without Protected  CatBoost  European Residence      0   0.000000
# 44  Without Protected  CatBoost  European Residence      1   0.722772
# 45  Without Protected  Ensemble             Sex_int      0   0.687500
# 46  Without Protected  Ensemble             Sex_int      1   0.720000
# 47  Without Protected  Ensemble  Protected category      0   0.710280
# 48  Without Protected  Ensemble  Protected category      1   0.000000
# 49  Without Protected  Ensemble       Age Range_int      0   0.500000
# 50  Without Protected  Ensemble       Age Range_int      1   0.545455
# 51  Without Protected  Ensemble       Age Range_int      2   0.702703
# 52  Without Protected  Ensemble       Age Range_int      3   0.772727
# 53  Without Protected  Ensemble       Age Range_int      4   0.800000
# 54  Without Protected  Ensemble       Age Range_int      5   0.875000
# 55  Without Protected  Ensemble       Age Range_int      6   0.727273
# 56  Without Protected  Ensemble   Italian Residence      0   1.000000
# 57  Without Protected  Ensemble   Italian Residence      1   0.707547
# 58  Without Protected  Ensemble  European Residence      0   0.000000
# 59  Without Protected  Ensemble  European Residence      1   0.710280
#
#       Recall
# 0   0.851852
# 1   0.791045
# 2   0.817204
# 3   0.000000
# 4   0.500000
# 5   0.750000
# 6   0.866667
# 7   0.842105
# 8   0.833333
# 9   1.000000
# 10  0.666667
# 11  1.000000
# 12  0.804348
# 13  0.000000
# 14  0.808511
# 15  0.925926
# 16  0.791045
# 17  0.827957
# 18  1.000000
# 19  0.666667
# 20  0.750000
# 21  0.866667
# 22  0.894737
# 23  0.750000
# 24  1.000000
# 25  0.750000
# 26  0.500000
# 27  0.836957
# 28  0.000000
# 29  0.829787
# 30  0.777778
# 31  0.776119
# 32  0.784946
# 33  0.000000
# 34  0.666667
# 35  0.750000
# 36  0.900000
# 37  0.684211
# 38  0.666667
# 39  1.000000
# 40  0.666667
# 41  0.500000
# 42  0.782609
# 43  0.000000
# 44  0.776596
# 45  0.814815
# 46  0.805970
# 47  0.817204
# 48  0.000000
# 49  0.666667
# 50  0.750000
# 51  0.866667
# 52  0.894737
# 53  0.666667
# 54  1.000000
# 55  0.666667
# 56  0.500000
# 57  0.815217
# 58  0.000000
# 59  0.808511

# %% [markdown]
# #### Analysis Summary: Impact of Including Protected Attributes on Model Performance and Fairness
#
# ##### Predictive Performance
# Including protected attributes in model training generally **improves predictive performance**. Both CatBoost and Ensemble models show higher precision, recall, and F1 scores when trained with protected attributes. Among the two, the Ensemble model consistently delivers better overall performance, with more pronounced improvements when protected attributes are included. Thus, incorporating these attributes helps models better capture relevant patterns, boosting accuracy.
#
# ##### Fairness Metrics
# The effect of including protected attributes on fairness is more nuanced:
#
# - For **Demographic Parity Difference**, models trained with protected attributes tend to show **reduced disparities**, especially notable in the Ensemble model. This suggests that explicitly including protected features can help balance positive prediction rates more fairly across groups.
#
# - For **Equalized Odds Difference**, disparities remain **high regardless of inclusion of protected attributes**, particularly for protected categories. This indicates that while including these attributes helps with some fairness aspects, it does not fully address all fairness concerns, especially error rate equalization between groups.
#
# ##### Group-wise Performance
# Including protected attributes helps produce more balanced precision and recall across groups for some protected attributes (e.g., sex), enhancing group-specific fairness and predictive quality. However, some minority or underrepresented groups still suffer from zero precision/recall in certain cases — indicating that including protected attributes alone is insufficient for fully fair outcomes.
#
# ##### Overall Takeaways
# - **Including protected attributes improves overall predictive accuracy and some fairness metrics (notably demographic parity).**
# - **Equalized odds fairness remains a challenge**, with disparities persisting in some subgroups.
# - The Ensemble model is generally more effective at balancing performance and fairness when using protected attributes.
# - Omitting protected attributes tends to degrade both performance and fairness awareness, potentially worsening fairness outcomes.
#
# ##### Recommendations
# - Prefer training with protected attributes, especially using the Ensemble model, to enhance both performance and fairness.
# - Supplement this with targeted strategies for subgroups that experience poor predictive performance.
# - Continue monitoring multiple fairness metrics to understand trade-offs and limitations.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fairness_df['Model_Setting'] = fairness_df['Model'] + ' | ' + fairness_df['Setting']

plt.figure(figsize=(18, 7))

fairness_df['Attribute_Model'] = fairness_df['Attribute'] + ' | ' + fairness_df['Model']

metrics = fairness_df['Metric'].unique()

for metric in metrics:
    plt.figure(figsize=(18, 7))
    subset = fairness_df[fairness_df['Metric'] == metric]

    order = sorted(subset['Attribute_Model'].unique(), key=lambda x: x.split(' | ')[0])
    
    sns.barplot(
        data=subset,
        x='Attribute_Model',
        y='Score',
        hue='Setting',          
        palette='Set2',
        ci=None,
        order=order
    )
    
    plt.title(f"Fairness Metric: {metric} (With vs Without Protected Attributes)")
    plt.axhline(0, linestyle='--', color='gray')
    plt.xticks(rotation=75, ha='right')
    plt.ylabel('Score')
    plt.xlabel('Attribute | Model')
    plt.legend(title='Setting')
    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

performance_df['Model+Setting'] = performance_df['Model'] + ' | ' + performance_df['Setting']
fairness_df['Model+Setting'] = fairness_df['Model'] + ' | ' + fairness_df['Setting']
pergroup_df['Model+Setting'] = pergroup_df['Model'] + ' | ' + pergroup_df['Setting']

plt.figure(figsize=(10, 6))
melted_perf = performance_df.melt(
    id_vars=['Model+Setting'], 
    value_vars=['Precision', 'Recall', 'F1 Score'],
    var_name='Metric', 
    value_name='Value'
)
sns.barplot(data=melted_perf, x='Model+Setting', y='Value', hue='Metric', palette='pastel')
plt.title("Model Performance: With vs Without Protected Attributes")
plt.xticks(rotation=45)
plt.ylim(0.6, 1)
plt.tight_layout()
plt.show()

import matplotlib.pyplot as plt
import seaborn as sns


for attr in protected_attributes:
    df_attr = pergroup_df[pergroup_df['Attribute'] == attr]

    for metric in ['Precision', 'Recall']:
        plt.figure(figsize=(12, 6))
        sns.barplot(
            data=df_attr,
            x='Group',
            y=metric,
            hue='Model+Setting',
            palette='Set2'
        )
        plt.title(f"{metric} by Group for '{attr}': With vs Without Protected Attributes")
        plt.ylim(0, 1)
        plt.xticks(rotation=45)
        plt.legend(title='Model + Setting')
        plt.tight_layout()
        plt.show()
